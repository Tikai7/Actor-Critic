# %% [markdown]
#  Copyright © Sorbonne University.
#
#  This source code is licensed under the MIT license found in the
#  LICENSE file in the root directory of this source tree.

# %% [markdown]
# ## Binômes :
# - ***Abdelkrim HALIMI***
# - ***Hatem AYED***

# %% [markdown]
# # Outlook
#
# In this notebook, you will code a naive actor-critic algorithm in the tabular case. Then you will tune it using grid search and Bayesian optimization, potentially using the [optuna](https://optuna.readthedocs.io/en/stable/) library.
# Finally, you will get the best hyper-parameters obtained with both methods and perform a statistical test to see if there is a statistically significant difference between these methods and with respect to naive hyper-parameter values.
#
# ## Install libraries

# %%
# Installs the necessary Python and system libraries
try:
    from easypip import easyimport, easyinstall, is_notebook
except ModuleNotFoundError as e:
    get_ipython().run_line_magic("pip", "install 'easypip>=1.2.0'")
    from easypip import easyimport, easyinstall, is_notebook

easyinstall("swig")
easyinstall("bbrl>=0.2.2")
easyinstall("bbrl_gymnasium>=0.2.0")
easyinstall("tensorboard")
easyinstall("moviepy")
easyinstall("box2d-kengz")
easyinstall("optuna")
easyinstall("gymnasium")
easyinstall("mazemdp")

import numpy as np
import os
from typing import List

import hydra
import optuna
import yaml
from omegaconf import OmegaConf, DictConfig

# For visualization
os.environ["VIDEO_FPS"] = "5"
if not os.path.isdir("./videos"):
    os.mkdir("./videos")

from IPython.display import Video

# %%
import torch
import torch.nn as nn
import numpy as np 
import seaborn as sns

# %%
import gymnasium as gym

from bbrl.utils.chrono import Chrono

import matplotlib
import matplotlib.pyplot as plt

from mazemdp.toolbox import sample_categorical
from mazemdp.mdp import Mdp
from bbrl_gymnasium.envs.maze_mdp import MazeMDPEnv
from gymnasium.wrappers.monitoring.video_recorder import VideoRecorder
from functools import partial

matplotlib.use("TkAgg")
# Out:
# Matplotlib backend: module://matplotlib_inline.backend_inline

# %% [markdown]
# # Step 1: Coding the naive Actor-critic algorithm
#
# We consider the naive actor-critic algorithm with a categorical policy.
# The algorithm learns a critic with the standard temporal difference mechanism
# using a learning rate $\alpha_{critic}$.
#
# We consider a value-based critic $V(s)$. The extension to an action value function $Q(s,a)$ is straightforward.
#
# To update the critic, the algorithm computes the temporal difference error:
#
# $$\delta_t = r(s_t, a_t) + \gamma V^{(n)}(s_{t+1})-V^{(n)}(s_t).$$
#
# Then it applies it to the critic:
#
# $$V^{(n+1)}(s_t) = V^{(n)}(s_t) + \alpha_{critic} \delta_t.$$
#
# To update the actor, the general idea is the same, using the temporal difference error with another learning rate $\alpha_{actor}$.
#
# However, naively applying the same learning rule would not ensure that the probabilities of all actions in a state sum to 1.
# Besides, when the temporal difference error $\delta_t$ is negative, it may happen that the probability of an action gets negative or null, which raises an issue when applying renormalization.
#
# So, instead of applying the naive rule, we apply the following one:
# $$
# \pi_{temp}(a_t|s_t) =  \begin{cases}
# \pi^{(i)}(a_t|s_t) + \alpha_{actor} \delta_t & \mathrm{if } \pi^{(i)}(a_t|s_t) + \alpha_{actor} \delta_t > 10^{-8}\\
# 10^{-8} & \mathrm{otherwise.} \\
# \end{cases}
# $$
#
# Then we can apply renormalization so that the probabilities of actions still sum to 1, with
# $$
# \forall a, \pi^{(i+1)}(a|s_t) = \frac{\pi_{temp}^{(i+1)}(a|s_t)} {\sum_{a'} \pi_{temp}^{(i+1)}(a'|s_t)}
# $$ with
# $$
# \pi_{temp}^{(i+1)}(a|s_t) =  \begin{cases}
# \pi_{temp}(a|s_t) & \mathrm{if } a = a_t\\
# \pi^{(i)}(a|s_t) & \mathrm{otherwise.} \\
# \end{cases}
# $$
#
# ## Exercise 1
#
# ### 1. Code the naive actor-critic algorithm as specified above.
#
# Some hints:
#
# - a good idea to build this code it to take inspiration from the code of Q-learning, to add an actor (a categorical policy), both learning rates,
# and to take care about the renormalization function.
#
# - for the next steps of this lab, having a function to repeatedly call your actor-critic algorithm and save the learning trajectories and
# norms of the value function is a good idea.

# %%
import gymnasium as gym
import numpy as np 

# Environment with 20% of walls and no negative reward when hitting a wall
env = gym.make(
    "MazeMDP-v0",
    kwargs={"width": 4, "height": 3, "ratio": 0.2, "hit": 0.0},
    render_mode="human",
)
env.reset()
env.unwrapped.init_draw("The maze")
# Out:
# <style>table.maze {
#     border-collapse: collapse;
# }
#
# td {
#     text-align: center;
# }
#
# table.maze td.cell {
#     position: relative;
#     border: 1px solid black;
# }
#
# table.maze td.cell div.agent {
#     position: absolute;
#     left: 25%;
#     top: 25%;;
#     width: 50%;
#     height: 50%;
#     border-radius: 100%;
#     background:rgba(69, 100, 186, 0.5);
# }
#
#
# td.wall {
#     background: black;
# }
#
# td.terminal {
#     background: rgb(246, 170, 246);
# }
#
# table.maze table td {
#     width: .5rem;
#     height: .5rem;
# }
#
#
#
# table.maze table td.arrow {
#     color: transparent;
#     font-weight: bold;
# }
#
# table.maze table td.value {
#     position: relative;
#     width: 2rem;
#     height: 2rem;
# }
#
# </style>
# VBox(children=(MazeWidget(cells=array([[ 0,  3, -1,  7],
#        [ 1,  4,  5,  8],
#        [ 2, -1,  6,  9]]), t…

# %%
def get_policy_from_actor(actor: np.ndarray) -> np.ndarray:
    return np.argmax(actor,axis=1)

def actor_critic(
    mdp: MazeMDPEnv,
    nb_episodes: int = 20,
    timeout: int = 50,
    alpha_critic : float = 0.5,
    alpha_actor : float=0.5,
    render: bool = True,
) -> tuple[np.ndarray, List[float]]:
    """
    Args:
        mdp: the environment
        nb_episodes: the number of episodes
        timeout: the maximum number of steps per episode
        alpha_critic: the critic learning rate
        alpha_actor: the actor learning rate
        render: whether to render the environment
    Returns:
        a_probs: the learned policy
        v: the learned value function
        v_list: the norm of the value function at
        time_list: the number of steps per episode
        mean_reward: the mean reward
    """

    # Initialize the state-action value function
    # alpha is the learning rate
    v = np.zeros(mdp.unwrapped.nb_states)  # initial state value v
    a_probs = np.ones((mdp.unwrapped.nb_states, mdp.action_space.n))/mdp.action_space.n 
    v_min = np.zeros(mdp.unwrapped.nb_states)
    v_list = []
    time_list = []
    reward_list = []
    # Run learning cycle
    mdp.timeout = timeout  # episode length

    if render:
        mdp.init_draw("Actor Critic")

    for _ in range(nb_episodes):
        
        reward = 0
        # Draw the first state of episode i using a uniform distribution over all the states
        x, _ = mdp.reset(uniform=True)
        cpt = 0

        terminated = False
        truncated = False

        while not (terminated or truncated):
            if render:
                mdp.draw_v_pi(v, get_policy_from_actor(a_probs))

            # Draw an action using a soft-max policy
            u = sample_categorical(a_probs[x])
            y, r, terminated, truncated, _ = mdp.step(u)
            # Update the state-action value function with q-Learning
            delta = r + mdp.gamma*v[y]*(1-terminated) - v[x]
            v[x] = v[x] + alpha_critic*delta

            temp = a_probs[x,u] + alpha_actor*delta
            a_probs[x, u] = temp if temp > 1e-8 else 1e-8
            a_probs[x] = a_probs[x]/a_probs[x].sum()

            x = y
            cpt = cpt + 1
            reward += r

        reward_list.append(reward)
        v_list.append(np.linalg.norm(np.maximum(v, v_min)))
        time_list.append(cpt)

    if render:
        mdp.current_state = 0
        mdp.draw_v_pi(v, get_policy_from_actor(a_probs))

    return a_probs, v, v_list, time_list, reward_list

# %%
NB_EPISODES = 100
TIMEOUT = 50
ALPHA_CRITIC = 0.5
ALPHA_ACTOR = 0.5

a, v, v_list, time_list, reward_list = actor_critic(
    env, alpha_critic=ALPHA_CRITIC,alpha_actor=ALPHA_ACTOR, nb_episodes=NB_EPISODES, timeout=TIMEOUT
)
# Out:
# /mnt/c/Cours-Sorbonne/M2/UE_DEEP/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.init_draw to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.init_draw` for environment variables or `env.get_wrapper_attr('init_draw')` that will search the reminding wrappers.
#   logger.warn(
# VBox(children=(MazeWidget(cells=array([[ 0,  3, -1,  7],
#        [ 1,  4,  5,  8],
#        [ 2, -1,  6,  9]]), t…
# /mnt/c/Cours-Sorbonne/M2/UE_DEEP/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.draw_v_pi to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.draw_v_pi` for environment variables or `env.get_wrapper_attr('draw_v_pi')` that will search the reminding wrappers.
#   logger.warn(
# /mnt/c/Cours-Sorbonne/M2/UE_DEEP/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.gamma to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.gamma` for environment variables or `env.get_wrapper_attr('gamma')` that will search the reminding wrappers.
#   logger.warn(

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(a, annot=True, fmt=".2f", cmap="viridis")
plt.title("Actor probabilities")
plt.show()

# %% [markdown]
# ### 2. Provide a plot function
#
# Your plot function should show the evolution through time of number of steps the agent takes to find the reward in the maze.
# If your algorithm works, this number of steps should decrease through time.
#
# Your plot function should also show a mean and a standard deviation (or some more advanced statistics) over a collection of learning runs.

# %%
class Plotter():

    @staticmethod
    def moving_average(data, window_size):
        return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

    @staticmethod
    def plot_steps_evolution(time_list, save_path="figure1"):
        mean = np.round(np.mean(time_list), 3)
        std = np.round(np.std(time_list), 3)
        q1 = np.round(np.percentile(time_list, 35),3)
        q3 = np.round(np.percentile(time_list, 75),3)
        median = np.round(np.median(time_list),3)
        max = np.round(np.max(time_list),3)
        min = np.round(np.min(time_list),3)

        time_list_smoothed = Plotter.moving_average(time_list, 10)

        plt.style.use("ggplot")
        plt.figure(figsize=(14, 7))

        # Plot des étapes par épisode
        plt.subplot(121)
        plt.plot(time_list, label="Steps per episode", color='blue', alpha=0.6)
        plt.plot(time_list_smoothed, label="Moving average of steps per episode", color='red', linewidth=2)
        plt.legend()
        plt.title("Number of Steps per Episode")
        plt.xlabel("Episode")
        plt.ylabel("Steps")
        plt.grid(True)

        # Boxplot des étapes par épisode
        plt.subplot(122)
        plt.boxplot(time_list, vert=False)
        plt.title(f"Box plot of steps per episode")
        plt.xlabel("Steps")
        plt.grid(True)

        handles, labels = plt.gca().get_legend_handles_labels()
        handles.extend([
            plt.Line2D([0], [0], color='yellow', lw=2),
            plt.Line2D([0], [0], color='yellow', lw=2),
            plt.Line2D([0], [0], color='green', lw=2),
            plt.Line2D([0], [0], color='purple', lw=2),
            plt.Line2D([0], [0], color='red', lw=2),
            plt.Line2D([0], [0], color='blue', lw=2),
            plt.Line2D([0], [0], color='blue', lw=2)
        ])
        labels.extend([
            f'Max : {max} steps', f'Min : {min} steps', 
            f'Mean : {mean} steps', f'Std : {std} steps', 
            f'Q1 : {q1} steps', f'Q3 : {q3} steps', 
            f'Median : {median} steps'
        ])
        
        plt.legend(handles, labels, loc='upper right')

        plt.tight_layout()
        plt.savefig(save_path)

        plt.show()

    @staticmethod
    def plot_multiples(liste, labels, save_path="figure2", title="Multiple plots", xlabel="Episode", ylabel="Value"):
        plt.style.use("ggplot")
        plt.figure(figsize=(14, 7))

        colors = ['blue', 'red', 'green', 'purple', 'orange']
        for i, l in enumerate(liste):
            if save_path == "steps_per_episode_multiple":
                plt.plot(Plotter.moving_average(l, 10), label=labels[i]+" smoothed", linewidth=4, alpha=1, color=colors[i])
            plt.plot(l, label=labels[i], alpha=0.4, color=colors[i])

        plt.legend()
        plt.title(title)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(save_path)
        plt.show()
    
    @staticmethod
    def compare_plots(results:dict):
        Plotter.plot_multiples(
            [results[i]['lists']["time_list"] for i in range(len(results))], 
            save_path="steps_per_episode_multiple",
            title="Steps per episode",
            xlabel="Episode",
            ylabel="Steps",
            labels=[results[i]["name"] for i in range(len(results))]
        ) 
        Plotter.plot_multiples(
            [results[i]['lists']["mean_reward"] for i in range(len(results))], 
            save_path="reward_per_episode multiple",
            title="Reward per episode",
            xlabel="Episode",
            ylabel="Reward",
            labels=[results[i]["name"] for i in range(len(results))]    
        ) 
        Plotter.plot_multiples(
            [results[i]['lists']["v_list"] for i in range(len(results))], 
            save_path="value_per_episode_multiple",
            title="Norm of value per episode",
            xlabel="Episode",
            ylabel="Norm of value",
            labels=[results[i]["name"] for i in range(len(results))]
        )

# %%
Plotter.plot_steps_evolution(time_list, "steps_per_episode")
Plotter.plot_steps_evolution(reward_list, "reward_per_episode")
Plotter.plot_steps_evolution(v_list, "value_function_per_episode")

# %% [markdown]
# ## Actor-critic hyper-parameters
#
# To represent the hyper-parameters of the experiments performed in this notebook, we suggest using the dictionary below.
# This dictionary can be read using omegaconf.
# Using it is not mandatory.
# You can also change the value of hyper-parameters or environment parameters at will.

# %%
ac_params = {
    "save_curves": False,
    "save_heatmap": True,
    "mdp": {
        "name": "MazeMDP-v0",
        "width": 5,
        "height": 5,
        "ratio": 0.2,
        "render_mode": "rgb_array",
    },
        
    "log_dir": "./tmp",
    "video_dir": "./tmp/videos",

    "nb_episodes": 100,
    "timeout": 200,
    "render": False, # True, # 
    "nb_repeats": 5,

    "alpha_critic": 0.5,
    "alpha_actor": 0.5,
}

# %% [markdown]
# ### 3. Test your code
#
# Once everything looks OK, save the obtained plot for your lab report

# %%
config = OmegaConf.create(ac_params)

env_config = gym.make(
    config.mdp.name,
    kwargs={
        "width": config.mdp.width,
        "height": config.mdp.height,
        "ratio": config.mdp.ratio,
        "hit": 0.0,
    },
    render_mode=config.mdp.render_mode,
)

a_probs, v, v_list, time_list, reward_list = actor_critic(
    env_config, alpha_critic=config.alpha_critic, 
    alpha_actor=config.alpha_actor, nb_episodes=config.nb_episodes, 
    timeout=config.timeout, render=False
)
# Out:
# /mnt/c/Cours-Sorbonne/M2/UE_DEEP/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.gamma to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.gamma` for environment variables or `env.get_wrapper_attr('gamma')` that will search the reminding wrappers.
#   logger.warn(

# %%
Plotter.plot_steps_evolution(time_list, save_path="steps_per_episode_config_0.png")

# %% [markdown]
# # Step 2: Tuning hyper-parameters
#
# In this part, you have to optimize two hyper-parameters of the actor-critic algorithm, namely the actor and critic learning rates.
# You have to do so using a simple grid search method and some Bayesian optimization method.
# For the latter, we suggest using the default sampler from [optuna](https://optuna.readthedocs.io/en/stable/).
# Follow the above link to understand how optuna works.
# Note that it also supports grid search and many other hyper-parameters tuning algorithms.
#
# You should make sure that the hyper-parameters tuning algorithms that you compare benefit from the same training budget
# We suggest 400 training runs overall for each method,
# which means 20 values each for the actor and the critic learning rates in the case of grid search.
#
# ## Exercise 2
#
# ### 1. Perform hyper-parameters tuning with two algorithms as suggested above.
#
# ### 2. Provide a "heatmap" of the norm of the value function given the hyper-parameters, after training for each pair of hyper-parameters.
#
# ### 3. Collect the value of the best hyper-parameters found with each algorithm. You will need them for Step 3.
#
# ### 4. Include in your report the heatmaps and the best hyper-parameters found for each method.

# %%
stats = []

class EnvManager():
    """
    Class to manage the environments
    Methods:
        - generate_envs
    """
    
    @staticmethod
    def generate_envs(nb_env):
        envs = [
            gym.make(
            config.mdp.name,
            kwargs={
                "width": config.mdp.width,
                "height": config.mdp.height,
                "ratio": config.mdp.ratio,
                "hit": 0.0,
            },
            render_mode=config.mdp.render_mode,
            ) for _ in range(nb_env)         
        ]
        return envs
    
envs = EnvManager.generate_envs(5)

class ObjectiveFunction():
    """
    Class to define the objective function to optimize
    Methods:
        - objective_by
    """

    @staticmethod
    def objective_by(trial : optuna.Trial, goal: str = "steps", n_iter: int = 15):
        """
        Args:
            trial: the trial
            goal: the goal to optimize, must be one of {"norm_v, mean_steps", "policy_entropy", "value_stability", "mean_reward"}
        Returns:
            the value of the objective function
        """

    
        global stats

        all_goals = {"norm_v", "mean_steps", "policy_entropy", "value_stability", "mean_reward"}

        if goal not in all_goals:
            raise ValueError(f"Unknown goal: {goal}, must be one of {all_goals}")
        
        alpha_critic = trial.suggest_float("alpha_critic", 1e-2, 1.0)
        alpha_actor = trial.suggest_float("alpha_actor", 1e-2, 1.0)
        

        env_a, env_v, env_v_list, env_time_list, env_mean_reward = [], [], [], [], []
        for env_i in envs:
            all_a, all_v, all_v_list, all_time_list, all_mean_reward = [], [], [], [], []             
            for _ in range(n_iter):
                a_probs, v, v_list, time_list, reward_list = actor_critic(
                    env_i, alpha_critic=alpha_critic, 
                    alpha_actor=alpha_actor, nb_episodes=config.nb_episodes, 
                    timeout=config.timeout, render=False
                )

                mean_reward = np.mean(reward_list)
                all_a.append(a_probs)
                all_v.append(v)
                all_v_list.append(v_list)
                all_time_list.append(np.mean(time_list))
                all_mean_reward.append(mean_reward)

            env_a.append(all_a)
            env_v.append(all_v)
            env_v_list.append(all_v_list)
            env_time_list.append(all_time_list)
            env_mean_reward.append(all_mean_reward)
        
        all_a = np.mean(env_a, axis=0)
        all_v = np.mean(env_v, axis=0)
        all_v_list = np.mean(env_v_list, axis=0)
        all_time_list = np.mean(env_time_list, axis=0)
        all_mean_reward = np.mean(env_mean_reward, axis=0)
        

        time_list_mean = np.mean(all_time_list)
        v_list_mean = np.mean(all_v_list, axis=0)
        a_probs_mean = np.mean(all_a, axis=0)
        v_mean = np.mean(all_v, axis=0)
        mean_reward = np.mean(all_mean_reward)

        stats.append({
            "params" : {
                "alpha_critic": alpha_critic,
                "alpha_actor": alpha_actor,
            },
            "lists" : {
                "time_list": all_time_list,
                "v_list": all_v_list,
                "a_probs": all_a,
                "v": all_v,
                "rewards": all_mean_reward,
            },
            "evaluation_metrics": {
                "mean_steps": -time_list_mean,
                "policy_entropy": -np.sum(a_probs_mean*np.log(a_probs_mean)),
                "value_stability": -np.std(v_list_mean),
                "mean_reward": mean_reward,
                "norm_v": np.max(v_list_mean),
            },
        })

        if goal == "mean_steps":
            return -time_list_mean
        elif goal == "policy_entropy":
            return -np.sum(a_probs_mean*np.log(a_probs_mean))
        elif goal == "value_stability":
            return -np.std(v_list_mean)
        elif goal == "mean_reward":
            return mean_reward
        elif goal == "norm_v":
            return np.max(v_list_mean)

class TuningAlgorithm():
    """
    Class to tune the hyperparameters of the actor-critic algorithm
    Methods:
        - tune_by_bayesian_optimization 
        - tune_by_grid_search
    """

    @staticmethod
    def tune_by_bayesian_optimization(objective = ObjectiveFunction.objective_by, goal: str = "mean_steps"):
        """ 
        Tune the hyperparameters of the actor-critic algorithm using Bayesian optimization
        Args:
            objective: the objective function to optimize
        """
        study = optuna.create_study(direction="maximize")
        objective = partial(objective, goal=goal, n_iter=15)
        study.optimize(objective, n_trials=400)
        
        print(f"Best parameters: {study.best_params}")
        print(f"Best score: {study.best_value}")
        study_results = study.trials_dataframe()
        study_results.to_csv("study_results_bayesian_opt.csv")
        return study.best_params, study 
    
    @staticmethod
    def tune_by_grid_search(objective = ObjectiveFunction.objective_by, goal: str = "mean_steps"):
        """
        Tune the hyperparameters of the actor-critic algorithm using grid search
        Args:
            objective: the objective function to optimize
        """
        search_space = {
            "alpha_critic": np.linspace(1e-2, 1.0, 20),
            "alpha_actor": np.linspace(1e-2, 1.0, 20)
        }
        sampler = optuna.samplers.GridSampler(search_space)
        study = optuna.create_study(direction="maximize", sampler=sampler)
        objective = partial(objective, goal=goal, n_iter=15)
        study.optimize(objective)

        print(f"Best parameters: {study.best_params}")
        print(f"Best score: {study.best_value}")

        study_results = study.trials_dataframe()
        study_results.to_csv("study_results_grid_search.csv")
        return study.best_params, study

# %% [markdown]
# ## Tune hyperparameters by grid search

# %%
stats = []
TuningAlgorithm.tune_by_grid_search(goal="norm_v")
np.save("stats_grid_search.npy", stats)
# Out:
# [I 2024-09-29 00:35:19,547] A new study created in memory with name: no-name-9972ffaf-4c0e-4ebf-a564-f6828ba319e8
# [I 2024-09-29 00:35:22,513] Trial 0 finished with value: 2.7658463265953936 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.32263157894736844}. Best is trial 0 with value: 2.7658463265953936.
# [I 2024-09-29 00:35:25,312] Trial 1 finished with value: 2.7600096476201474 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.791578947368421}. Best is trial 0 with value: 2.7658463265953936.
# [I 2024-09-29 00:35:30,374] Trial 2 finished with value: 1.5115200528470827 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.8957894736842106}. Best is trial 0 with value: 2.7658463265953936.
# [I 2024-09-29 00:35:33,192] Trial 3 finished with value: 2.861439905372243 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.4789473684210527}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:35:36,301] Trial 4 finished with value: 2.593051481517049 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.6352631578947369}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:35:43,077] Trial 5 finished with value: 0.3847514126722439 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.16631578947368422}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:35:46,003] Trial 6 finished with value: 2.8263540646261225 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.37473684210526315}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:35:50,781] Trial 7 finished with value: 1.497619300489131 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.6873684210526316}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:35:55,958] Trial 8 finished with value: 1.4550730445410687 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.37473684210526315}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:35:58,576] Trial 9 finished with value: 2.856222751807513 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.5310526315789474}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:36:03,412] Trial 10 finished with value: 2.3916209646811857 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.06210526315789474}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:36:06,325] Trial 11 finished with value: 2.7995098455772762 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.32263157894736844}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:36:09,409] Trial 12 finished with value: 2.763529273673473 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.2705263157894737}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:36:12,178] Trial 13 finished with value: 2.727644372250561 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.8957894736842106}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:36:18,983] Trial 14 finished with value: 1.6289957438667273 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.01}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:36:22,949] Trial 15 finished with value: 2.652882526753663 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.11421052631578947}. Best is trial 3 with value: 2.861439905372243.
# [I 2024-09-29 00:36:25,505] Trial 16 finished with value: 2.862529057702798 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.7394736842105263}. Best is trial 16 with value: 2.862529057702798.
# [I 2024-09-29 00:36:31,912] Trial 17 finished with value: 0.4093684004957704 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.37473684210526315}. Best is trial 16 with value: 2.862529057702798.
# [I 2024-09-29 00:36:35,097] Trial 18 finished with value: 2.572171271026732 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.5310526315789474}. Best is trial 16 with value: 2.862529057702798.
# [I 2024-09-29 00:36:37,813] Trial 19 finished with value: 2.8946159235436 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.4789473684210527}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:36:40,538] Trial 20 finished with value: 2.861611395589843 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.4268421052631579}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:36:43,382] Trial 21 finished with value: 2.724376226880198 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.6873684210526316}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:36:47,102] Trial 22 finished with value: 2.319238058122167 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.32263157894736844}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:36:50,195] Trial 23 finished with value: 2.3894641734915227 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.8957894736842106}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:36:53,028] Trial 24 finished with value: 2.8436627723991355 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.4268421052631579}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:36:55,546] Trial 25 finished with value: 2.8649406908142963 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.791578947368421}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:36:58,868] Trial 26 finished with value: 2.7349176335176772 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.16631578947368422}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:05,676] Trial 27 finished with value: 1.7047741774780731 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.01}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:08,561] Trial 28 finished with value: 2.6040407721488186 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.7394736842105263}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:13,172] Trial 29 finished with value: 1.8795852058903497 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.2705263157894737}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:16,034] Trial 30 finished with value: 2.7568847306658175 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.4268421052631579}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:19,459] Trial 31 finished with value: 2.2237680467021748 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.791578947368421}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:21,864] Trial 32 finished with value: 2.890440610855118 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.8436842105263158}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:24,891] Trial 33 finished with value: 2.516711027266699 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.5831578947368421}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:28,965] Trial 34 finished with value: 2.3302107372739282 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.16631578947368422}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:32,497] Trial 35 finished with value: 2.7052414935597904 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.16631578947368422}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:35,812] Trial 36 finished with value: 2.6649152898340254 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.21842105263157896}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:38,634] Trial 37 finished with value: 2.823172887541916 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.4268421052631579}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:41,431] Trial 38 finished with value: 2.8824256423757624 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.4268421052631579}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:44,572] Trial 39 finished with value: 2.778454481155728 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 1.0}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:51,310] Trial 40 finished with value: 0.39586708773421536 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.2705263157894737}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:37:55,091] Trial 41 finished with value: 1.961264759045624 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.8436842105263158}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:01,890] Trial 42 finished with value: 1.4965620625408755 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.01}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:09,163] Trial 43 finished with value: 1.0380035238651357 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.01}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:11,821] Trial 44 finished with value: 2.874352650396743 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.7394736842105263}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:15,778] Trial 45 finished with value: 2.5600910103671737 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.11421052631578947}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:18,342] Trial 46 finished with value: 2.8782132653242187 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.9478947368421053}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:21,139] Trial 47 finished with value: 2.883713950223516 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.6352631578947369}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:24,089] Trial 48 finished with value: 2.851337563540555 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.37473684210526315}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:26,905] Trial 49 finished with value: 2.8477949748122144 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.5831578947368421}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:29,829] Trial 50 finished with value: 2.6687825235002953 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.6352631578947369}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:34,046] Trial 51 finished with value: 2.3361705055457143 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.37473684210526315}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:36,659] Trial 52 finished with value: 2.878839850280223 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.7394736842105263}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:39,957] Trial 53 finished with value: 2.8005394825070846 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.4268421052631579}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:46,618] Trial 54 finished with value: 0.41840341781930307 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.7394736842105263}. Best is trial 19 with value: 2.8946159235436.
# [I 2024-09-29 00:38:49,395] Trial 55 finished with value: 2.901123387414601 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.791578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:38:53,440] Trial 56 finished with value: 2.5221995880765657 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.11421052631578947}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:00,189] Trial 57 finished with value: 1.567383609646413 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.01}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:05,286] Trial 58 finished with value: 2.089733278725503 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.06210526315789474}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:09,700] Trial 59 finished with value: 2.235856780829111 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.11421052631578947}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:13,160] Trial 60 finished with value: 2.6575986601924426 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.16631578947368422}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:15,716] Trial 61 finished with value: 2.84001696428806 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.6873684210526316}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:22,550] Trial 62 finished with value: 1.4155304592074933 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.01}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:24,972] Trial 63 finished with value: 2.8793345917587723 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.8957894736842106}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:27,718] Trial 64 finished with value: 2.803591847650829 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.4789473684210527}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:30,270] Trial 65 finished with value: 2.832340347586381 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.9478947368421053}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:33,489] Trial 66 finished with value: 2.473629219419657 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.37473684210526315}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:40,232] Trial 67 finished with value: 1.4541427676159826 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.01}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:42,960] Trial 68 finished with value: 2.822915795707404 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.37473684210526315}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:45,463] Trial 69 finished with value: 2.8074286836322058 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.791578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:52,127] Trial 70 finished with value: 1.5181461121736446 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.01}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:39:58,264] Trial 71 finished with value: 0.421163029777773 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.6873684210526316}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:01,936] Trial 72 finished with value: 2.5256768389392263 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.16631578947368422}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:08,801] Trial 73 finished with value: 0.359905210670713 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.06210526315789474}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:12,147] Trial 74 finished with value: 2.587083042891078 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.2705263157894737}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:18,928] Trial 75 finished with value: 1.7056245788591655 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.01}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:22,186] Trial 76 finished with value: 2.2279737076284127 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.9478947368421053}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:25,258] Trial 77 finished with value: 2.3866735871732137 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.791578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:29,838] Trial 78 finished with value: 1.5254230354289555 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.9478947368421053}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:32,462] Trial 79 finished with value: 2.7716659855111203 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.8436842105263158}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:34,912] Trial 80 finished with value: 2.898203887073622 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.8436842105263158}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:39,181] Trial 81 finished with value: 2.221575384349929 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.16631578947368422}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:43,080] Trial 82 finished with value: 2.593380940797222 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.11421052631578947}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:46,581] Trial 83 finished with value: 2.512273490494274 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.2705263157894737}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:53,121] Trial 84 finished with value: 0.41752317362990665 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.791578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:40:55,897] Trial 85 finished with value: 2.7641105309223235 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.5831578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:00,289] Trial 86 finished with value: 1.8996003790218419 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.32263157894736844}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:02,763] Trial 87 finished with value: 2.874877902515091 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.9478947368421053}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:05,160] Trial 88 finished with value: 2.893943804464378 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 1.0}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:08,186] Trial 89 finished with value: 2.5051999301322554 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.8436842105263158}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:14,214] Trial 90 finished with value: 0.435301692674189 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 1.0}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:16,806] Trial 91 finished with value: 2.861609608071798 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.6352631578947369}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:20,605] Trial 92 finished with value: 2.608888411846637 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.11421052631578947}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:27,344] Trial 93 finished with value: 1.563047948814222 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.01}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:30,078] Trial 94 finished with value: 2.780690652716906 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.4789473684210527}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:33,459] Trial 95 finished with value: 2.5524465918309422 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.37473684210526315}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:36,302] Trial 96 finished with value: 2.803571942115814 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.32263157894736844}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:38,849] Trial 97 finished with value: 2.80970102146112 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 1.0}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:41,986] Trial 98 finished with value: 2.379060441068268 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.6873684210526316}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:45,041] Trial 99 finished with value: 2.3977688838113362 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.9478947368421053}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:47,688] Trial 100 finished with value: 2.7955323042079696 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.6352631578947369}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:52,143] Trial 101 finished with value: 2.0589646219396873 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.16631578947368422}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:54,611] Trial 102 finished with value: 2.8455801734686026 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.791578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:41:57,388] Trial 103 finished with value: 2.87622386609426 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.37473684210526315}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:00,831] Trial 104 finished with value: 2.2122041557480876 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.7394736842105263}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:06,741] Trial 105 finished with value: 0.43065696218274524 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.8957894736842106}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:12,158] Trial 106 finished with value: 1.410924888294364 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.21842105263157896}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:14,714] Trial 107 finished with value: 2.7821443805232 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.8957894736842106}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:17,451] Trial 108 finished with value: 2.8123701320531707 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.37473684210526315}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:19,885] Trial 109 finished with value: 2.8845178913075076 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.7394736842105263}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:23,097] Trial 110 finished with value: 2.7546392970089704 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.21842105263157896}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:26,375] Trial 111 finished with value: 2.6341374022023114 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.21842105263157896}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:28,830] Trial 112 finished with value: 2.897108006790393 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.7394736842105263}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:35,102] Trial 113 finished with value: 1.2318241824407756 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.06210526315789474}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:37,990] Trial 114 finished with value: 2.516034297765778 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.9478947368421053}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:40,580] Trial 115 finished with value: 2.88044364033567 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.5310526315789474}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:43,120] Trial 116 finished with value: 2.8822175768776273 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.6352631578947369}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:47,191] Trial 117 finished with value: 2.4536067446079453 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.11421052631578947}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:49,723] Trial 118 finished with value: 2.8892142599530515 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.5831578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:52,999] Trial 119 finished with value: 2.220828662591498 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.8957894736842106}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:56,248] Trial 120 finished with value: 2.686575835897153 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.21842105263157896}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:42:59,688] Trial 121 finished with value: 2.1985023833106836 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.5831578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:02,282] Trial 122 finished with value: 2.8599393609522994 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.5831578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:04,924] Trial 123 finished with value: 2.8475087402447037 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.5831578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:07,412] Trial 124 finished with value: 2.899202040374226 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.9478947368421053}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:11,753] Trial 125 finished with value: 1.9026253308141317 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.37473684210526315}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:17,547] Trial 126 finished with value: 1.604415346743969 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.06210526315789474}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:20,019] Trial 127 finished with value: 2.8379031588390276 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.6352631578947369}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:22,476] Trial 128 finished with value: 2.8113341231651803 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.8957894736842106}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:25,324] Trial 129 finished with value: 2.6855468374581437 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.4268421052631579}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:28,201] Trial 130 finished with value: 2.751413357369005 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.37473684210526315}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:30,600] Trial 131 finished with value: 2.858033342145091 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 1.0}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:34,570] Trial 132 finished with value: 2.4114657074952457 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.16631578947368422}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:40,843] Trial 133 finished with value: 0.4136331576830809 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.6352631578947369}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:43,483] Trial 134 finished with value: 2.8908714005709917 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.5310526315789474}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:48,746] Trial 135 finished with value: 1.414521949961004 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.2705263157894737}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:51,447] Trial 136 finished with value: 2.8243302725350268 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.791578947368421}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:54,345] Trial 137 finished with value: 2.8420001781630635 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.4789473684210527}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:43:57,222] Trial 138 finished with value: 2.6055810593545927 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.8436842105263158}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:44:03,950] Trial 139 finished with value: 1.7696200095669907 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.01}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:44:07,702] Trial 140 finished with value: 2.346169548610921 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.4268421052631579}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:44:10,765] Trial 141 finished with value: 2.5798107355295556 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.4789473684210527}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:44:15,742] Trial 142 finished with value: 2.2422428724820547 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.06210526315789474}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:44:18,719] Trial 143 finished with value: 2.7823365580143813 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.2705263157894737}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:44:22,254] Trial 144 finished with value: 2.204087633203772 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.6873684210526316}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:44:26,452] Trial 145 finished with value: 2.135848518377556 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.2705263157894737}. Best is trial 55 with value: 2.901123387414601.
# [I 2024-09-29 00:44:28,877] Trial 146 finished with value: 2.9141655525059136 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.8957894736842106}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:44:32,074] Trial 147 finished with value: 2.4875247210514333 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.6352631578947369}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:44:34,728] Trial 148 finished with value: 2.8707336984442 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.5831578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:44:37,801] Trial 149 finished with value: 2.7959541440846136 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.2705263157894737}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:44:40,403] Trial 150 finished with value: 2.7913304826348275 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:44:46,996] Trial 151 finished with value: 0.3986033055895496 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:44:49,652] Trial 152 finished with value: 2.7682120718515693 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:44:52,763] Trial 153 finished with value: 2.7424440537323758 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.2705263157894737}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:44:55,512] Trial 154 finished with value: 2.8577003220383004 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.5310526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:44:58,390] Trial 155 finished with value: 2.8344837733465047 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:01,054] Trial 156 finished with value: 2.8905548895908155 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.6873684210526316}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:04,508] Trial 157 finished with value: 2.528808320170976 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:07,201] Trial 158 finished with value: 2.8806682921399154 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.4789473684210527}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:09,918] Trial 159 finished with value: 2.8724986825167402 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:14,605] Trial 160 finished with value: 1.4998167560613187 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:17,508] Trial 161 finished with value: 2.7736974577605538 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:22,307] Trial 162 finished with value: 2.313005755572475 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:24,945] Trial 163 finished with value: 2.898272207344702 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.9478947368421053}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:29,130] Trial 164 finished with value: 1.9197108867263342 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.4268421052631579}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:33,846] Trial 165 finished with value: 2.3371307066704605 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:36,455] Trial 166 finished with value: 2.804907419958317 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.5831578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:39,718] Trial 167 finished with value: 2.7749157261537265 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.21842105263157896}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:43,448] Trial 168 finished with value: 2.3992956062462403 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.21842105263157896}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:49,077] Trial 169 finished with value: 1.364012501932243 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.16631578947368422}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:52,211] Trial 170 finished with value: 2.6439201703278394 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.4268421052631579}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:45:56,165] Trial 171 finished with value: 1.9423381058669087 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:02,478] Trial 172 finished with value: 0.4151116253919993 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.5310526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:05,030] Trial 173 finished with value: 2.837831417350726 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 1.0}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:07,725] Trial 174 finished with value: 2.7901470703625306 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.5831578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:10,526] Trial 175 finished with value: 2.6648493178089185 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:13,746] Trial 176 finished with value: 2.6236902210838995 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.2705263157894737}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:17,956] Trial 177 finished with value: 2.311632964827243 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.11421052631578947}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:24,221] Trial 178 finished with value: 0.4193660645038216 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:26,650] Trial 179 finished with value: 2.9123332465555243 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 1.0}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:29,950] Trial 180 finished with value: 2.3675729637500127 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.5831578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:33,409] Trial 181 finished with value: 2.658588681513118 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.16631578947368422}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:36,226] Trial 182 finished with value: 2.8267011817732093 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:40,638] Trial 183 finished with value: 1.5283741293438458 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 1.0}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:46,953] Trial 184 finished with value: 0.4080180661634183 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.5831578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:49,677] Trial 185 finished with value: 2.775786651417295 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.5310526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:54,570] Trial 186 finished with value: 2.215758839479152 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:46:59,599] Trial 187 finished with value: 1.4694603800391406 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.4789473684210527}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:05,620] Trial 188 finished with value: 0.4295077511595362 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.9478947368421053}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:08,281] Trial 189 finished with value: 2.824784645509682 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.6873684210526316}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:12,216] Trial 190 finished with value: 2.4849311575965487 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.11421052631578947}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:14,934] Trial 191 finished with value: 2.7332791940544676 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:17,561] Trial 192 finished with value: 2.8490070494745203 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.8957894736842106}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:22,482] Trial 193 finished with value: 2.13559692091753 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:29,503] Trial 194 finished with value: 1.2732004503382675 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.01}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:32,205] Trial 195 finished with value: 2.8878975783312284 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.5310526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:34,913] Trial 196 finished with value: 2.8527392000062326 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.37473684210526315}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:37,518] Trial 197 finished with value: 2.8283906918958377 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.5310526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:39,915] Trial 198 finished with value: 2.912905344750727 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.9478947368421053}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:44,771] Trial 199 finished with value: 1.4886886171030995 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.5831578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:47,617] Trial 200 finished with value: 2.8380810538736814 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:50,234] Trial 201 finished with value: 2.8739622834491763 and parameters: {'alpha_critic': 0.8436842105263158, 'alpha_actor': 0.5831578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:52,886] Trial 202 finished with value: 2.869680292126852 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.5310526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:55,354] Trial 203 finished with value: 2.8829506888339393 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.6873684210526316}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:47:57,943] Trial 204 finished with value: 2.891673655314662 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.6873684210526316}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:00,638] Trial 205 finished with value: 2.668965225595017 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.791578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:03,350] Trial 206 finished with value: 2.8852569512230515 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.5831578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:07,974] Trial 207 finished with value: 2.362644430009864 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:11,369] Trial 208 finished with value: 2.368349122732339 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.5310526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:13,929] Trial 209 finished with value: 2.8679227839296524 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 1.0}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:17,730] Trial 210 finished with value: 2.4714886323058654 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.16631578947368422}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:23,138] Trial 211 finished with value: 1.950150590847946 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:25,686] Trial 212 finished with value: 2.8461917654689173 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:30,250] Trial 213 finished with value: 2.126032189432194 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.11421052631578947}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:35,032] Trial 214 finished with value: 1.489012103678088 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.6352631578947369}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:38,068] Trial 215 finished with value: 2.69686083964182 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:41,366] Trial 216 finished with value: 2.7206193178898364 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.21842105263157896}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:44,445] Trial 217 finished with value: 2.70787855145008 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.2705263157894737}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:47,630] Trial 218 finished with value: 2.567962880081896 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.4268421052631579}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:50,170] Trial 219 finished with value: 2.774821515713966 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 1.0}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:53,459] Trial 220 finished with value: 2.2206012694225117 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 1.0}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:48:57,242] Trial 221 finished with value: 1.9605610550975592 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.8957894736842106}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:49:03,953] Trial 222 finished with value: 0.3792441727225396 and parameters: {'alpha_critic': 0.01, 'alpha_actor': 0.11421052631578947}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 00:49:11,962] Trial 223 finished with value: 1.7786677044347736 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.01}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:37:59,894] Trial 224 finished with value: 2.380363598855998 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:38:03,477] Trial 225 finished with value: 2.7399137880247637 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.16631578947368422}. Best is trial 146 with value: 2.9141655525059136.
# ...
# [I 2024-09-29 01:44:09,659] Trial 327 finished with value: 1.4371278513673067 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:12,530] Trial 328 finished with value: 2.517930117456886 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.8957894736842106}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:15,338] Trial 329 finished with value: 2.609874369611041 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 0.9478947368421053}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:18,601] Trial 330 finished with value: 2.6878205044376346 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.21842105263157896}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:23,285] Trial 331 finished with value: 1.8430470897438052 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.21842105263157896}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:26,085] Trial 332 finished with value: 2.664930005232954 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.6873684210526316}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:29,103] Trial 333 finished with value: 2.8245662261211404 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.2705263157894737}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:31,556] Trial 334 finished with value: 2.828144819058119 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:35,341] Trial 335 finished with value: 2.6341171371521086 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.11421052631578947}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:39,825] Trial 336 finished with value: 1.5175279182844295 and parameters: {'alpha_critic': 0.06210526315789474, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:42,283] Trial 337 finished with value: 2.8968555720747795 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.6352631578947369}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:44,751] Trial 338 finished with value: 2.8876908425535968 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.8957894736842106}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:50,051] Trial 339 finished with value: 1.7464478543884108 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.11421052631578947}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:53,742] Trial 340 finished with value: 2.4364647905150876 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.2705263157894737}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:56,402] Trial 341 finished with value: 2.7286049428753567 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.9478947368421053}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:44:58,890] Trial 342 finished with value: 2.8576204551381768 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.6873684210526316}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:01,448] Trial 343 finished with value: 2.86538864155474 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.8957894736842106}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:05,993] Trial 344 finished with value: 2.442693162128642 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:09,846] Trial 345 finished with value: 2.5336451281412375 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.11421052631578947}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:12,666] Trial 346 finished with value: 2.6716111431128358 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.8957894736842106}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:15,814] Trial 347 finished with value: 2.656722155761354 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:18,323] Trial 348 finished with value: 2.803249203210744 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:23,381] Trial 349 finished with value: 2.1752014011865404 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:27,024] Trial 350 finished with value: 2.1862858393513567 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.4789473684210527}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:30,792] Trial 351 finished with value: 2.1819445060699008 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.4268421052631579}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:33,556] Trial 352 finished with value: 2.779292107668118 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.37473684210526315}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:36,785] Trial 353 finished with value: 2.36843705795747 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 0.6352631578947369}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:40,927] Trial 354 finished with value: 1.9353827964301735 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.5310526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:45,617] Trial 355 finished with value: 2.280851347177188 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:50,412] Trial 356 finished with value: 2.28321788169806 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:53,561] Trial 357 finished with value: 2.609817697729815 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.32263157894736844}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:57,084] Trial 358 finished with value: 2.4735749957726427 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.4789473684210527}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:45:59,591] Trial 359 finished with value: 2.860909736258323 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.9478947368421053}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:02,332] Trial 360 finished with value: 2.7254828811088463 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:06,140] Trial 361 finished with value: 1.950826366257623 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.9478947368421053}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:09,196] Trial 362 finished with value: 2.6273569924911455 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.37473684210526315}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:12,156] Trial 363 finished with value: 2.5065198384637903 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:14,759] Trial 364 finished with value: 2.8035000017184064 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.9478947368421053}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:17,479] Trial 365 finished with value: 2.8754577572042312 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.4268421052631579}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:20,664] Trial 366 finished with value: 2.8027208119887437 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.21842105263157896}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:23,264] Trial 367 finished with value: 2.8901697659901546 and parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:25,808] Trial 368 finished with value: 2.892248009413108 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:28,443] Trial 369 finished with value: 2.8708768311943573 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.4789473684210527}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:32,019] Trial 370 finished with value: 2.202922705284903 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.6352631578947369}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:35,028] Trial 371 finished with value: 2.785181968311398 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.2705263157894737}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:38,084] Trial 372 finished with value: 2.500778462370719 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.6873684210526316}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:41,551] Trial 373 finished with value: 2.626836981037582 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.16631578947368422}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:44,066] Trial 374 finished with value: 2.8685032015427203 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:49,167] Trial 375 finished with value: 2.0458076202082576 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:52,442] Trial 376 finished with value: 2.4802050401030384 and parameters: {'alpha_critic': 0.2705263157894737, 'alpha_actor': 0.4268421052631579}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:54,916] Trial 377 finished with value: 2.911520842838319 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:46:57,910] Trial 378 finished with value: 2.3873324788610293 and parameters: {'alpha_critic': 0.21842105263157896, 'alpha_actor': 1.0}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:00,646] Trial 379 finished with value: 2.8416605028063615 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.4268421052631579}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:03,375] Trial 380 finished with value: 2.6154323194784035 and parameters: {'alpha_critic': 0.32263157894736844, 'alpha_actor': 1.0}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:08,071] Trial 381 finished with value: 2.4756495811474157 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.06210526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:10,892] Trial 382 finished with value: 2.821470776805093 and parameters: {'alpha_critic': 0.6873684210526316, 'alpha_actor': 0.4789473684210527}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:13,395] Trial 383 finished with value: 2.8740688689512095 and parameters: {'alpha_critic': 0.7394736842105263, 'alpha_actor': 0.791578947368421}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:16,760] Trial 384 finished with value: 2.5939026356209776 and parameters: {'alpha_critic': 0.4268421052631579, 'alpha_actor': 0.21842105263157896}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:20,304] Trial 385 finished with value: 2.585717882832881 and parameters: {'alpha_critic': 0.5310526315789474, 'alpha_actor': 0.16631578947368422}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:23,800] Trial 386 finished with value: 2.5403056438254072 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.21842105263157896}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:26,239] Trial 387 finished with value: 2.8553292015551426 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.7394736842105263}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:30,166] Trial 388 finished with value: 1.9488504246560752 and parameters: {'alpha_critic': 0.11421052631578947, 'alpha_actor': 0.6352631578947369}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:32,763] Trial 389 finished with value: 2.8872138972879418 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.6873684210526316}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:35,426] Trial 390 finished with value: 2.8070209188891 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.5310526315789474}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:42,206] Trial 391 finished with value: 1.5552848333636526 and parameters: {'alpha_critic': 0.4789473684210527, 'alpha_actor': 0.01}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:44,947] Trial 392 finished with value: 2.874648935625672 and parameters: {'alpha_critic': 1.0, 'alpha_actor': 0.8957894736842106}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:47,508] Trial 393 finished with value: 2.858375459652574 and parameters: {'alpha_critic': 0.791578947368421, 'alpha_actor': 0.4789473684210527}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:50,134] Trial 394 finished with value: 2.81842905066299 and parameters: {'alpha_critic': 0.5831578947368421, 'alpha_actor': 0.6352631578947369}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:53,528] Trial 395 finished with value: 2.2122993695568485 and parameters: {'alpha_critic': 0.16631578947368422, 'alpha_actor': 0.8436842105263158}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:56,199] Trial 396 finished with value: 2.8199672611790363 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.4789473684210527}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:47:59,152] Trial 397 finished with value: 2.790367609893385 and parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.2705263157894737}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:48:03,382] Trial 398 finished with value: 2.3683379090548837 and parameters: {'alpha_critic': 0.37473684210526315, 'alpha_actor': 0.11421052631578947}. Best is trial 146 with value: 2.9141655525059136.
# [I 2024-09-29 01:48:06,154] Trial 399 finished with value: 2.801087436713995 and parameters: {'alpha_critic': 0.6352631578947369, 'alpha_actor': 0.4268421052631579}. Best is trial 146 with value: 2.9141655525059136.
# Best parameters: {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.8957894736842106}
# Best score: 2.9141655525059136

# %% [markdown]
# ## Tune hyperparameters by bayesian optimization

# %%
stats = []
TuningAlgorithm.tune_by_bayesian_optimization(goal="norm_v")
np.save("stats_bayesian_optimization.npy", stats)
# Out:
# [I 2024-09-29 01:48:38,691] A new study created in memory with name: no-name-9047f6e3-2207-40ac-80be-f06bb21cf8dc
# /mnt/c/Cours-Sorbonne/M2/UE_DEEP/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.gamma to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.gamma` for environment variables or `env.get_wrapper_attr('gamma')` that will search the reminding wrappers.
#   logger.warn(
# [I 2024-09-29 01:48:41,799] Trial 0 finished with value: 2.7031851396711035 and parameters: {'alpha_critic': 0.541068587715524, 'alpha_actor': 0.26478361641097153}. Best is trial 0 with value: 2.7031851396711035.
# [I 2024-09-29 01:48:45,333] Trial 1 finished with value: 2.680878993247266 and parameters: {'alpha_critic': 0.8460301305701706, 'alpha_actor': 0.15029122629285344}. Best is trial 0 with value: 2.7031851396711035.
# [I 2024-09-29 01:48:48,423] Trial 2 finished with value: 2.5329223331943305 and parameters: {'alpha_critic': 0.292540113304887, 'alpha_actor': 0.4880705463795225}. Best is trial 0 with value: 2.7031851396711035.
# [I 2024-09-29 01:48:50,888] Trial 3 finished with value: 2.8989919560945028 and parameters: {'alpha_critic': 0.950191220737934, 'alpha_actor': 0.8193144305994512}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:48:53,819] Trial 4 finished with value: 2.8321627673879344 and parameters: {'alpha_critic': 0.919025877871304, 'alpha_actor': 0.30661207876995406}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:48:57,116] Trial 5 finished with value: 2.6915200855120784 and parameters: {'alpha_critic': 0.7387968544846307, 'alpha_actor': 0.18901462016695145}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:48:59,610] Trial 6 finished with value: 2.8374745133998855 and parameters: {'alpha_critic': 0.6439897464312969, 'alpha_actor': 0.6661350454189814}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:49:03,358] Trial 7 finished with value: 2.6572821024197273 and parameters: {'alpha_critic': 0.9775911166049791, 'alpha_actor': 0.1253486041296282}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:49:06,055] Trial 8 finished with value: 2.747797698760882 and parameters: {'alpha_critic': 0.45278235299473873, 'alpha_actor': 0.6808849934539365}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:49:10,513] Trial 9 finished with value: 2.3530776808292733 and parameters: {'alpha_critic': 0.5514642670092216, 'alpha_actor': 0.07738056853223975}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:49:15,125] Trial 10 finished with value: 1.4591923688714157 and parameters: {'alpha_critic': 0.05753683370441759, 'alpha_actor': 0.9745539987126863}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:49:17,620] Trial 11 finished with value: 2.868753096600199 and parameters: {'alpha_critic': 0.7008810366223617, 'alpha_actor': 0.8057016835564981}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:49:20,059] Trial 12 finished with value: 2.8833476117492602 and parameters: {'alpha_critic': 0.7797542183589545, 'alpha_actor': 0.9005238145660135}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:49:22,578] Trial 13 finished with value: 2.8911245469332405 and parameters: {'alpha_critic': 0.8254872232912794, 'alpha_actor': 0.97789851366708}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:49:25,282] Trial 14 finished with value: 2.887406939542167 and parameters: {'alpha_critic': 0.978727463595895, 'alpha_actor': 0.7840400394359741}. Best is trial 3 with value: 2.8989919560945028.
# [I 2024-09-29 01:49:27,717] Trial 15 finished with value: 2.904223542627764 and parameters: {'alpha_critic': 0.8630584020835506, 'alpha_actor': 0.9921443318177365}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:31,126] Trial 16 finished with value: 2.2956019613794707 and parameters: {'alpha_critic': 0.19354543810376612, 'alpha_actor': 0.5289342788345522}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:33,771] Trial 17 finished with value: 2.726260939440539 and parameters: {'alpha_critic': 0.42772369838996693, 'alpha_actor': 0.8577140617320776}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:36,314] Trial 18 finished with value: 2.8986852526332516 and parameters: {'alpha_critic': 0.8749841008206188, 'alpha_actor': 0.6899212066292744}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:39,075] Trial 19 finished with value: 2.803587537866453 and parameters: {'alpha_critic': 0.6324886025201369, 'alpha_actor': 0.4669200039521988}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:42,028] Trial 20 finished with value: 2.839687728545354 and parameters: {'alpha_critic': 0.9995551559610074, 'alpha_actor': 0.9976872838808352}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:44,590] Trial 21 finished with value: 2.8765881655664898 and parameters: {'alpha_critic': 0.8663888590677066, 'alpha_actor': 0.6945690155432186}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:47,111] Trial 22 finished with value: 2.8999986126966046 and parameters: {'alpha_critic': 0.8866536646492187, 'alpha_actor': 0.6015381161503309}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:49,740] Trial 23 finished with value: 2.862085157031759 and parameters: {'alpha_critic': 0.749767137019876, 'alpha_actor': 0.5969470182429201}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:52,298] Trial 24 finished with value: 2.8901642190551353 and parameters: {'alpha_critic': 0.9046433696057128, 'alpha_actor': 0.8872110532701044}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:55,081] Trial 25 finished with value: 2.808006443205626 and parameters: {'alpha_critic': 0.6565505012485334, 'alpha_actor': 0.3969511958119572}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:49:57,548] Trial 26 finished with value: 2.9031482856096194 and parameters: {'alpha_critic': 0.9148443613377758, 'alpha_actor': 0.775217710160095}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:50:00,036] Trial 27 finished with value: 2.8849245271528194 and parameters: {'alpha_critic': 0.7939829675278718, 'alpha_actor': 0.7612190833800799}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:50:02,979] Trial 28 finished with value: 2.669203658393937 and parameters: {'alpha_critic': 0.3736284020718957, 'alpha_actor': 0.5982739797835498}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:50:05,700] Trial 29 finished with value: 2.7888999099089498 and parameters: {'alpha_critic': 0.5389190322440968, 'alpha_actor': 0.5918853392332875}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:50:08,205] Trial 30 finished with value: 2.848080399320918 and parameters: {'alpha_critic': 0.5848623272382534, 'alpha_actor': 0.9153834730042538}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:50:10,715] Trial 31 finished with value: 2.8909166613410195 and parameters: {'alpha_critic': 0.9253635877932438, 'alpha_actor': 0.8339170303492343}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:50:13,300] Trial 32 finished with value: 2.894124816298882 and parameters: {'alpha_critic': 0.8261919911363094, 'alpha_actor': 0.7346742640115592}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:50:15,943] Trial 33 finished with value: 2.899612167149774 and parameters: {'alpha_critic': 0.9134350650634839, 'alpha_actor': 0.8271999720687677}. Best is trial 15 with value: 2.904223542627764.
# [I 2024-09-29 01:50:18,377] Trial 34 finished with value: 2.905394178979651 and parameters: {'alpha_critic': 0.8632339835550822, 'alpha_actor': 0.932423569434462}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:20,879] Trial 35 finished with value: 2.8848570353611818 and parameters: {'alpha_critic': 0.7172129438435579, 'alpha_actor': 0.9460180060645125}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:23,335] Trial 36 finished with value: 2.8963357586130565 and parameters: {'alpha_critic': 0.8091412550468816, 'alpha_actor': 0.9220062522082162}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:26,268] Trial 37 finished with value: 2.842603492283054 and parameters: {'alpha_critic': 0.85365131748189, 'alpha_actor': 0.33337117430895297}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:28,976] Trial 38 finished with value: 2.87814327126716 and parameters: {'alpha_critic': 0.9432861788121354, 'alpha_actor': 0.7414245817118645}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:31,456] Trial 39 finished with value: 2.8964833584030436 and parameters: {'alpha_critic': 0.8932285639263302, 'alpha_actor': 0.6412312108512082}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:34,106] Trial 40 finished with value: 2.8300772192135657 and parameters: {'alpha_critic': 0.6878643307852763, 'alpha_actor': 0.518530154271781}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:36,624] Trial 41 finished with value: 2.901041137137901 and parameters: {'alpha_critic': 0.9390326929059426, 'alpha_actor': 0.8580372441232978}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:39,038] Trial 42 finished with value: 2.8950103400733584 and parameters: {'alpha_critic': 0.7734472781703415, 'alpha_actor': 0.9425329089623361}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:41,544] Trial 43 finished with value: 2.9036788913470253 and parameters: {'alpha_critic': 0.9395234061584709, 'alpha_actor': 0.8698743166591256}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:44,223] Trial 44 finished with value: 2.8648053114849565 and parameters: {'alpha_critic': 0.9587611135245583, 'alpha_actor': 0.8743772927176705}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:47,213] Trial 45 finished with value: 2.8220250871806285 and parameters: {'alpha_critic': 0.9934684790181062, 'alpha_actor': 0.9961436151666666}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:49,588] Trial 46 finished with value: 2.890932976360423 and parameters: {'alpha_critic': 0.8380273466309953, 'alpha_actor': 0.8613605626360229}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:52,168] Trial 47 finished with value: 2.8976903263111495 and parameters: {'alpha_critic': 0.9406365117435656, 'alpha_actor': 0.785067940269619}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:50:57,800] Trial 48 finished with value: 0.7776807496106729 and parameters: {'alpha_critic': 0.02131193897107858, 'alpha_actor': 0.9370245760484933}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:00,283] Trial 49 finished with value: 2.8836527111731627 and parameters: {'alpha_critic': 0.7453451795217221, 'alpha_actor': 0.8234565754838286}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:03,155] Trial 50 finished with value: 2.539085889956829 and parameters: {'alpha_critic': 0.28048741306116276, 'alpha_actor': 0.8681684713631044}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:05,525] Trial 51 finished with value: 2.895313913288037 and parameters: {'alpha_critic': 0.8815241714666529, 'alpha_actor': 0.9026961078330871}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:08,212] Trial 52 finished with value: 2.861951074468946 and parameters: {'alpha_critic': 0.9550532549079038, 'alpha_actor': 0.9530403848154261}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:10,738] Trial 53 finished with value: 2.8887635471303694 and parameters: {'alpha_critic': 0.8543284178476215, 'alpha_actor': 0.7227487275544162}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:13,247] Trial 54 finished with value: 2.902371577303138 and parameters: {'alpha_critic': 0.903994101259314, 'alpha_actor': 0.7806632834945795}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:15,900] Trial 55 finished with value: 2.8822938095301387 and parameters: {'alpha_critic': 0.9957433770512006, 'alpha_actor': 0.78568925883132}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:18,336] Trial 56 finished with value: 2.8843583038213305 and parameters: {'alpha_critic': 0.7959147146860917, 'alpha_actor': 0.8213878652065548}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:21,935] Trial 57 finished with value: 2.7795094413365997 and parameters: {'alpha_critic': 0.9291931319137984, 'alpha_actor': 0.22997840987895435}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:25,589] Trial 58 finished with value: 2.0297469227485663 and parameters: {'alpha_critic': 0.12468534511398494, 'alpha_actor': 0.967314122767013}. Best is trial 34 with value: 2.905394178979651.
# [I 2024-09-29 01:51:28,042] Trial 59 finished with value: 2.9141173517035397 and parameters: {'alpha_critic': 0.9061510028324744, 'alpha_actor': 0.892255074619706}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:33,898] Trial 60 finished with value: 1.9672349324124496 and parameters: {'alpha_critic': 0.7707144586117487, 'alpha_actor': 0.024711168742742984}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:36,496] Trial 61 finished with value: 2.893874837350757 and parameters: {'alpha_critic': 0.9646012493509809, 'alpha_actor': 0.903249228394679}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:39,014] Trial 62 finished with value: 2.908384699266345 and parameters: {'alpha_critic': 0.908462222079635, 'alpha_actor': 0.8588590194105417}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:41,445] Trial 63 finished with value: 2.9088939474736946 and parameters: {'alpha_critic': 0.8833674741875188, 'alpha_actor': 0.7868508605270175}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:43,786] Trial 64 finished with value: 2.9068625577623304 and parameters: {'alpha_critic': 0.8302732543715178, 'alpha_actor': 0.9761935514835507}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:46,236] Trial 65 finished with value: 2.8944225163072774 and parameters: {'alpha_critic': 0.82904193396674, 'alpha_actor': 0.9964211205612177}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:48,599] Trial 66 finished with value: 2.906782978368594 and parameters: {'alpha_critic': 0.8719069722723105, 'alpha_actor': 0.9009063157931908}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:50,982] Trial 67 finished with value: 2.9008180563477257 and parameters: {'alpha_critic': 0.8475902682176109, 'alpha_actor': 0.9662895766805983}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:53,411] Trial 68 finished with value: 2.8733413333842557 and parameters: {'alpha_critic': 0.7272949091013374, 'alpha_actor': 0.9069873981402312}. Best is trial 59 with value: 2.9141173517035397.
# [I 2024-09-29 01:51:55,789] Trial 69 finished with value: 2.916861519962526 and parameters: {'alpha_critic': 0.872894179427056, 'alpha_actor': 0.9336152602355641}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:51:58,158] Trial 70 finished with value: 2.8959276883203264 and parameters: {'alpha_critic': 0.8105015917269035, 'alpha_actor': 0.8396728865768501}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:00,630] Trial 71 finished with value: 2.896094010052473 and parameters: {'alpha_critic': 0.8639940740345414, 'alpha_actor': 0.9337724166425863}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:02,986] Trial 72 finished with value: 2.9113946900493004 and parameters: {'alpha_critic': 0.8854659357898641, 'alpha_actor': 0.9768871114297467}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:05,543] Trial 73 finished with value: 2.887460149581315 and parameters: {'alpha_critic': 0.8856564495417107, 'alpha_actor': 0.8983295478200927}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:07,956] Trial 74 finished with value: 2.895798213754093 and parameters: {'alpha_critic': 0.7717632472522971, 'alpha_actor': 0.9696972702513339}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:10,466] Trial 75 finished with value: 2.900267217033529 and parameters: {'alpha_critic': 0.8961049816902806, 'alpha_actor': 0.9253029108960734}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:13,106] Trial 76 finished with value: 2.770599767015718 and parameters: {'alpha_critic': 0.4798936338496992, 'alpha_actor': 0.8045231958688712}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:15,455] Trial 77 finished with value: 2.8959656566023577 and parameters: {'alpha_critic': 0.8179027897900847, 'alpha_actor': 0.8865993033413795}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:17,866] Trial 78 finished with value: 2.8787250167212237 and parameters: {'alpha_critic': 0.6926571013586038, 'alpha_actor': 0.9664541861620393}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:20,239] Trial 79 finished with value: 2.8435781746562836 and parameters: {'alpha_critic': 0.6096200653124696, 'alpha_actor': 0.8432934765965263}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:23,019] Trial 80 finished with value: 2.831420258794616 and parameters: {'alpha_critic': 0.9730741591887173, 'alpha_actor': 0.9998911224961847}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:25,473] Trial 81 finished with value: 2.885393785790968 and parameters: {'alpha_critic': 0.8704336192341651, 'alpha_actor': 0.9368478434434511}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:27,946] Trial 82 finished with value: 2.8978706374583054 and parameters: {'alpha_critic': 0.9041833859901013, 'alpha_actor': 0.9211421962155067}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:30,339] Trial 83 finished with value: 2.9118629452317584 and parameters: {'alpha_critic': 0.8437256234892192, 'alpha_actor': 0.9779951317989873}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:32,758] Trial 84 finished with value: 2.9001869163358243 and parameters: {'alpha_critic': 0.829353470051499, 'alpha_actor': 0.8844354066121421}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:35,227] Trial 85 finished with value: 2.8934202784427203 and parameters: {'alpha_critic': 0.7907828467842014, 'alpha_actor': 0.9759233887993131}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:37,691] Trial 86 finished with value: 2.898055585405365 and parameters: {'alpha_critic': 0.9144623790529156, 'alpha_actor': 0.9488859413743066}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:40,437] Trial 87 finished with value: 2.848074385562562 and parameters: {'alpha_critic': 0.8552863474270074, 'alpha_actor': 0.4104978609501894}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:42,930] Trial 88 finished with value: 2.899724419135355 and parameters: {'alpha_critic': 0.8770735710145986, 'alpha_actor': 0.8531171288365724}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:45,473] Trial 89 finished with value: 2.7127339342476042 and parameters: {'alpha_critic': 0.40623623543626297, 'alpha_actor': 0.886759315440917}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:47,967] Trial 90 finished with value: 2.8814116174613775 and parameters: {'alpha_critic': 0.7524035932162227, 'alpha_actor': 0.8032202657122779}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:50,338] Trial 91 finished with value: 2.9018695953312292 and parameters: {'alpha_critic': 0.8374991667565455, 'alpha_actor': 0.9592929872524236}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:52,709] Trial 92 finished with value: 2.908279217227916 and parameters: {'alpha_critic': 0.923227057013787, 'alpha_actor': 0.9861568407765124}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:55,193] Trial 93 finished with value: 2.8885484516520505 and parameters: {'alpha_critic': 0.9189790070686642, 'alpha_actor': 0.9216534645144716}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:52:57,904] Trial 94 finished with value: 2.848591212361668 and parameters: {'alpha_critic': 0.9704571867136135, 'alpha_actor': 0.977962148032214}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:00,534] Trial 95 finished with value: 2.875813447359765 and parameters: {'alpha_critic': 0.9379972666759858, 'alpha_actor': 0.9868219274592667}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:02,914] Trial 96 finished with value: 2.9111021135439272 and parameters: {'alpha_critic': 0.8895919546534222, 'alpha_actor': 0.914336794726443}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:05,365] Trial 97 finished with value: 2.8995137760384924 and parameters: {'alpha_critic': 0.8922383770695201, 'alpha_actor': 0.9099792843682434}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:07,842] Trial 98 finished with value: 2.898329108229184 and parameters: {'alpha_critic': 0.8103319775147659, 'alpha_actor': 0.8750148512272352}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:10,526] Trial 99 finished with value: 2.877857698277348 and parameters: {'alpha_critic': 0.9564142075361568, 'alpha_actor': 0.9568267394106265}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:13,065] Trial 100 finished with value: 2.8892162954552663 and parameters: {'alpha_critic': 0.9273224802304784, 'alpha_actor': 0.5572422120860318}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:15,419] Trial 101 finished with value: 2.9015427238428404 and parameters: {'alpha_critic': 0.8489948742598847, 'alpha_actor': 0.9407877446392322}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:17,839] Trial 102 finished with value: 2.9016811337022497 and parameters: {'alpha_critic': 0.8733307211322937, 'alpha_actor': 0.9235931685362194}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:20,359] Trial 103 finished with value: 2.8971771670706707 and parameters: {'alpha_critic': 0.9085785876561653, 'alpha_actor': 0.8543163056622364}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:22,993] Trial 104 finished with value: 2.882436302721961 and parameters: {'alpha_critic': 0.9820373366872615, 'alpha_actor': 0.899221469442419}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:25,318] Trial 105 finished with value: 2.884951960344615 and parameters: {'alpha_critic': 0.7910545864065252, 'alpha_actor': 0.9810467721879571}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:27,681] Trial 106 finished with value: 2.9076159561552193 and parameters: {'alpha_critic': 0.8907235459520134, 'alpha_actor': 0.949983056307837}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:30,040] Trial 107 finished with value: 2.9144310633962194 and parameters: {'alpha_critic': 0.8892410860450428, 'alpha_actor': 0.9496637373210388}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:32,383] Trial 108 finished with value: 2.9029554749086715 and parameters: {'alpha_critic': 0.8917147588845231, 'alpha_actor': 0.9993044366037066}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:34,917] Trial 109 finished with value: 2.8958064795348895 and parameters: {'alpha_critic': 0.8389756400275247, 'alpha_actor': 0.9480969504336764}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:38,718] Trial 110 finished with value: 2.6667035924192755 and parameters: {'alpha_critic': 0.9461841213587647, 'alpha_actor': 0.13217314151046528}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:41,185] Trial 111 finished with value: 2.908287775632698 and parameters: {'alpha_critic': 0.8778594410990297, 'alpha_actor': 0.9510100355132932}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:43,592] Trial 112 finished with value: 2.895197164175491 and parameters: {'alpha_critic': 0.8970930252522845, 'alpha_actor': 0.9585549190513744}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:46,068] Trial 113 finished with value: 2.8985108699409095 and parameters: {'alpha_critic': 0.9198565640566909, 'alpha_actor': 0.9816638124042025}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:48,432] Trial 114 finished with value: 2.9142685375904316 and parameters: {'alpha_critic': 0.861012449708778, 'alpha_actor': 0.933040196432528}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:50,783] Trial 115 finished with value: 2.8971161687101348 and parameters: {'alpha_critic': 0.8615014125668093, 'alpha_actor': 0.9159729158754988}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:53,375] Trial 116 finished with value: 2.901806200250648 and parameters: {'alpha_critic': 0.9269750422056683, 'alpha_actor': 0.8754256162570837}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:55,981] Trial 117 finished with value: 2.892486338567161 and parameters: {'alpha_critic': 0.9553522891341347, 'alpha_actor': 0.9379247334682943}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:53:58,354] Trial 118 finished with value: 2.9085279702306996 and parameters: {'alpha_critic': 0.885581290002618, 'alpha_actor': 0.8379237767967042}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:00,874] Trial 119 finished with value: 2.887283161832278 and parameters: {'alpha_critic': 0.8122289218680222, 'alpha_actor': 0.7651934166121983}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:03,453] Trial 120 finished with value: 2.8984231087383296 and parameters: {'alpha_critic': 0.9890978720064308, 'alpha_actor': 0.6497108877138611}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:05,899] Trial 121 finished with value: 2.8820996751682637 and parameters: {'alpha_critic': 0.8783886295631759, 'alpha_actor': 0.8176666751870031}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:08,300] Trial 122 finished with value: 2.9076526175897754 and parameters: {'alpha_critic': 0.9098479035004035, 'alpha_actor': 0.8428749477112306}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:10,763] Trial 123 finished with value: 2.906511019341253 and parameters: {'alpha_critic': 0.90778623723532, 'alpha_actor': 0.8394732045780496}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:13,195] Trial 124 finished with value: 2.89892376944969 and parameters: {'alpha_critic': 0.8489231766134204, 'alpha_actor': 0.7494558399787519}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:16,237] Trial 125 finished with value: 2.448318463434707 and parameters: {'alpha_critic': 0.24764527340976117, 'alpha_actor': 0.7101006904520185}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:18,741] Trial 126 finished with value: 2.894559547909943 and parameters: {'alpha_critic': 0.940348095604054, 'alpha_actor': 0.8688238241915704}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:21,185] Trial 127 finished with value: 2.8938663009797123 and parameters: {'alpha_critic': 0.8689260458020659, 'alpha_actor': 0.8019054829790848}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:23,575] Trial 128 finished with value: 2.907519078798759 and parameters: {'alpha_critic': 0.9209273608445289, 'alpha_actor': 0.8858203460458675}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:26,006] Trial 129 finished with value: 2.8948328076613232 and parameters: {'alpha_critic': 0.8263834320278695, 'alpha_actor': 0.8347537032723898}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:28,850] Trial 130 finished with value: 2.86096657704194 and parameters: {'alpha_critic': 0.9710498713850333, 'alpha_actor': 0.9133316762265286}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:31,411] Trial 131 finished with value: 2.898392362449812 and parameters: {'alpha_critic': 0.8868997694881487, 'alpha_actor': 0.9553969664150663}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:34,429] Trial 132 finished with value: 2.892670421423379 and parameters: {'alpha_critic': 0.8860952800677288, 'alpha_actor': 0.9345313420250198}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:37,108] Trial 133 finished with value: 2.901155200231541 and parameters: {'alpha_critic': 0.8548281147944397, 'alpha_actor': 0.9006476577469561}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:39,748] Trial 134 finished with value: 2.8999203781182885 and parameters: {'alpha_critic': 0.9085101816709668, 'alpha_actor': 0.9529435123323092}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:42,461] Trial 135 finished with value: 2.895605978700843 and parameters: {'alpha_critic': 0.9373810546765946, 'alpha_actor': 0.8614040779718224}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:45,170] Trial 136 finished with value: 2.863795998358053 and parameters: {'alpha_critic': 0.8937406811711599, 'alpha_actor': 0.4792965375282152}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:47,744] Trial 137 finished with value: 2.9080134249259686 and parameters: {'alpha_critic': 0.8680874629967659, 'alpha_actor': 0.9307193756277333}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:50,593] Trial 138 finished with value: 2.8112587703375653 and parameters: {'alpha_critic': 0.5360880230415913, 'alpha_actor': 0.8905802584099127}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:53,522] Trial 139 finished with value: 2.9066148497211164 and parameters: {'alpha_critic': 0.8466076837559113, 'alpha_actor': 0.9243414033519861}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:56,096] Trial 140 finished with value: 2.90048623652649 and parameters: {'alpha_critic': 0.8089360863067366, 'alpha_actor': 0.8478921181595253}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:54:58,530] Trial 141 finished with value: 2.896711050509692 and parameters: {'alpha_critic': 0.8721118835673443, 'alpha_actor': 0.9746873196823475}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:01,012] Trial 142 finished with value: 2.9054109354573594 and parameters: {'alpha_critic': 0.9083630044655608, 'alpha_actor': 0.9356502049493386}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:03,411] Trial 143 finished with value: 2.89785595320224 and parameters: {'alpha_critic': 0.8649247141290494, 'alpha_actor': 0.9969326829907039}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:06,086] Trial 144 finished with value: 2.8714032727187893 and parameters: {'alpha_critic': 0.9507721482573085, 'alpha_actor': 0.9633800568191289}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:08,646] Trial 145 finished with value: 2.8944400108484776 and parameters: {'alpha_critic': 0.9252308388304346, 'alpha_actor': 0.9154229054224804}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:11,183] Trial 146 finished with value: 2.914837292079967 and parameters: {'alpha_critic': 0.8901671760564244, 'alpha_actor': 0.8909250729466955}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:13,878] Trial 147 finished with value: 2.903978370394181 and parameters: {'alpha_critic': 0.8351266289523934, 'alpha_actor': 0.8863662406277518}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:16,858] Trial 148 finished with value: 2.9059590155276727 and parameters: {'alpha_critic': 0.9023983308523682, 'alpha_actor': 0.8133673424253207}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:19,442] Trial 149 finished with value: 2.88968526376912 and parameters: {'alpha_critic': 0.8775687157021101, 'alpha_actor': 0.8682999216639049}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:22,145] Trial 150 finished with value: 2.8729024468117106 and parameters: {'alpha_critic': 0.9289471800481034, 'alpha_actor': 0.8998663234763148}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:24,635] Trial 151 finished with value: 2.9040831832374447 and parameters: {'alpha_critic': 0.8880140236904858, 'alpha_actor': 0.9448564693594859}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:27,155] Trial 152 finished with value: 2.9067726228510344 and parameters: {'alpha_critic': 0.8576157034813859, 'alpha_actor': 0.9790657221260806}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:29,578] Trial 153 finished with value: 2.8626137270706624 and parameters: {'alpha_critic': 0.6683008039849355, 'alpha_actor': 0.9249278553976711}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:31,990] Trial 154 finished with value: 2.906703000176556 and parameters: {'alpha_critic': 0.9009302522947015, 'alpha_actor': 0.9513733149262842}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:34,445] Trial 155 finished with value: 2.8933659184875475 and parameters: {'alpha_critic': 0.8376394506909772, 'alpha_actor': 0.9091402888501035}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:37,107] Trial 156 finished with value: 2.887619648944288 and parameters: {'alpha_critic': 0.9535944530034344, 'alpha_actor': 0.9678426573514578}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:39,555] Trial 157 finished with value: 2.894855070440002 and parameters: {'alpha_critic': 0.8745520341245642, 'alpha_actor': 0.8514870691512724}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:42,622] Trial 158 finished with value: 2.8179967221925475 and parameters: {'alpha_critic': 0.9225859130998769, 'alpha_actor': 0.28233752854034305}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:45,056] Trial 159 finished with value: 2.894896165454931 and parameters: {'alpha_critic': 0.8170597909139188, 'alpha_actor': 0.9304622939619454}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:47,861] Trial 160 finished with value: 2.6133711346458486 and parameters: {'alpha_critic': 0.3307015170914569, 'alpha_actor': 0.8804521181305344}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:50,457] Trial 161 finished with value: 2.9086450729132047 and parameters: {'alpha_critic': 0.9155438083286939, 'alpha_actor': 0.8892344015877905}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:52,986] Trial 162 finished with value: 2.9006122895037953 and parameters: {'alpha_critic': 0.8934591351169002, 'alpha_actor': 0.9063367246413051}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:55,437] Trial 163 finished with value: 2.888764013671098 and parameters: {'alpha_critic': 0.9160222716329198, 'alpha_actor': 0.8277014479846642}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:55:57,895] Trial 164 finished with value: 2.9045891426466115 and parameters: {'alpha_critic': 0.8535774250624126, 'alpha_actor': 0.9982769766579103}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:00,280] Trial 165 finished with value: 2.8952336869557413 and parameters: {'alpha_critic': 0.8811224686665285, 'alpha_actor': 0.9438127727169707}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:02,877] Trial 166 finished with value: 2.904897731629291 and parameters: {'alpha_critic': 0.9318746813860102, 'alpha_actor': 0.7909072956431813}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:05,384] Trial 167 finished with value: 2.9013496843829736 and parameters: {'alpha_critic': 0.9046819522773812, 'alpha_actor': 0.8673018482328348}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:08,052] Trial 168 finished with value: 2.8676408845559185 and parameters: {'alpha_critic': 0.9760138858258347, 'alpha_actor': 0.8922888916369354}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:10,518] Trial 169 finished with value: 2.90469014460233 and parameters: {'alpha_critic': 0.8677056780394444, 'alpha_actor': 0.9639860059418024}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:13,172] Trial 170 finished with value: 2.8695206919537837 and parameters: {'alpha_critic': 0.9512785342370637, 'alpha_actor': 0.9235118967973954}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:16,534] Trial 171 finished with value: 2.7456865874690433 and parameters: {'alpha_critic': 0.9204211521571405, 'alpha_actor': 0.18337976577452386}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:19,135] Trial 172 finished with value: 2.9033293782641256 and parameters: {'alpha_critic': 0.8972107027504861, 'alpha_actor': 0.8735652505641087}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:21,654] Trial 173 finished with value: 2.8861345769529283 and parameters: {'alpha_critic': 0.9380515304207755, 'alpha_actor': 0.8908693455478596}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:24,087] Trial 174 finished with value: 2.909594499151073 and parameters: {'alpha_critic': 0.8819928061938834, 'alpha_actor': 0.8559262475809533}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:26,490] Trial 175 finished with value: 2.892539156947264 and parameters: {'alpha_critic': 0.851187216568525, 'alpha_actor': 0.8485644968940679}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:28,892] Trial 176 finished with value: 2.913358716213868 and parameters: {'alpha_critic': 0.8818672738829344, 'alpha_actor': 0.8232461281957584}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:31,376] Trial 177 finished with value: 2.8969055305325453 and parameters: {'alpha_critic': 0.8729490823250039, 'alpha_actor': 0.8195774758477872}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:33,851] Trial 178 finished with value: 2.8821528468743285 and parameters: {'alpha_critic': 0.8338662939798307, 'alpha_actor': 0.8326956364421426}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:37,717] Trial 179 finished with value: 1.9291579718903764 and parameters: {'alpha_critic': 0.11055459822928332, 'alpha_actor': 0.7833538091801765}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:40,206] Trial 180 finished with value: 2.8976576366908673 and parameters: {'alpha_critic': 0.8852774791612384, 'alpha_actor': 0.85759917787501}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:42,611] Trial 181 finished with value: 2.9110511805677315 and parameters: {'alpha_critic': 0.9043802676002607, 'alpha_actor': 0.9461013502972663}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:45,128] Trial 182 finished with value: 2.891366687875975 and parameters: {'alpha_critic': 0.912626555771057, 'alpha_actor': 0.9091256001344007}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:47,505] Trial 183 finished with value: 2.9094355289168656 and parameters: {'alpha_critic': 0.8619440654331657, 'alpha_actor': 0.9814956966421462}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:49,991] Trial 184 finished with value: 2.894183609779055 and parameters: {'alpha_critic': 0.867623066664137, 'alpha_actor': 0.9682077957219457}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:52,447] Trial 185 finished with value: 2.906247963278756 and parameters: {'alpha_critic': 0.8492226974860685, 'alpha_actor': 0.9848250877157357}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:54,961] Trial 186 finished with value: 2.890995889883775 and parameters: {'alpha_critic': 0.8240765670666303, 'alpha_actor': 0.9388598060211728}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:57,406] Trial 187 finished with value: 2.905678685097056 and parameters: {'alpha_critic': 0.8911581188472724, 'alpha_actor': 0.9840228232131727}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:56:59,842] Trial 188 finished with value: 2.902368753882683 and parameters: {'alpha_critic': 0.8780780707515623, 'alpha_actor': 0.9557268295137621}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:02,337] Trial 189 finished with value: 2.892033249100452 and parameters: {'alpha_critic': 0.8532053744561966, 'alpha_actor': 0.9265884617704478}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:04,989] Trial 190 finished with value: 2.8779605917124584 and parameters: {'alpha_critic': 0.9024878747580062, 'alpha_actor': 0.975195047208955}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:07,502] Trial 191 finished with value: 2.900051685324431 and parameters: {'alpha_critic': 0.9106547930461086, 'alpha_actor': 0.8394478868649794}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:09,892] Trial 192 finished with value: 2.909811441078358 and parameters: {'alpha_critic': 0.8651875988488671, 'alpha_actor': 0.8757770314820803}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:12,544] Trial 193 finished with value: 2.840165044105951 and parameters: {'alpha_critic': 0.8017502511508996, 'alpha_actor': 0.4365499461152202}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:14,993] Trial 194 finished with value: 2.8777932675694373 and parameters: {'alpha_critic': 0.8649892045744044, 'alpha_actor': 0.90598552881319}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:17,424] Trial 195 finished with value: 2.9020299043035482 and parameters: {'alpha_critic': 0.8395758865475139, 'alpha_actor': 0.8835466998288273}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:19,813] Trial 196 finished with value: 2.892354466989988 and parameters: {'alpha_critic': 0.8808122013320103, 'alpha_actor': 0.9382869694357086}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:22,204] Trial 197 finished with value: 2.9095908033576636 and parameters: {'alpha_critic': 0.8917369574945494, 'alpha_actor': 0.9153242781169688}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:24,739] Trial 198 finished with value: 2.9041424989505495 and parameters: {'alpha_critic': 0.9279535808794686, 'alpha_actor': 0.9123030411580217}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:27,204] Trial 199 finished with value: 2.9112621443160984 and parameters: {'alpha_critic': 0.892066016004799, 'alpha_actor': 0.8701384945149284}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:29,658] Trial 200 finished with value: 2.901800276199363 and parameters: {'alpha_critic': 0.9015350645036544, 'alpha_actor': 0.8672283104270732}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:32,083] Trial 201 finished with value: 2.8945959097221015 and parameters: {'alpha_critic': 0.8869689712614581, 'alpha_actor': 0.8837303209756574}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:34,668] Trial 202 finished with value: 2.8981764830543497 and parameters: {'alpha_critic': 0.9422914154217001, 'alpha_actor': 0.8046580137060915}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:37,217] Trial 203 finished with value: 2.8984597811706725 and parameters: {'alpha_critic': 0.8658893824866395, 'alpha_actor': 0.8625907613258734}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:39,727] Trial 204 finished with value: 2.9130096297668167 and parameters: {'alpha_critic': 0.9153596466952629, 'alpha_actor': 0.8939096859514198}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:42,224] Trial 205 finished with value: 2.9028209812779493 and parameters: {'alpha_critic': 0.8884542845793654, 'alpha_actor': 0.8952707381924215}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:44,679] Trial 206 finished with value: 2.8978464586549095 and parameters: {'alpha_critic': 0.8529220160867709, 'alpha_actor': 0.871091326073342}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:47,135] Trial 207 finished with value: 2.891232400477435 and parameters: {'alpha_critic': 0.9105885534145146, 'alpha_actor': 0.9106021445950983}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:49,519] Trial 208 finished with value: 2.9069224313249795 and parameters: {'alpha_critic': 0.8880445570405433, 'alpha_actor': 0.8249691694275935}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:52,052] Trial 209 finished with value: 2.881828223901412 and parameters: {'alpha_critic': 0.8383234125180992, 'alpha_actor': 0.8494833720908428}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:54,612] Trial 210 finished with value: 2.892205327716517 and parameters: {'alpha_critic': 0.9287844517953155, 'alpha_actor': 0.8911724923956965}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:57,052] Trial 211 finished with value: 2.9089096219933217 and parameters: {'alpha_critic': 0.9131790959833439, 'alpha_actor': 0.952241250340394}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:57:59,494] Trial 212 finished with value: 2.9042409785076386 and parameters: {'alpha_critic': 0.9014077215456544, 'alpha_actor': 0.9493752353114715}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:58:01,936] Trial 213 finished with value: 2.9026322126491237 and parameters: {'alpha_critic': 0.873423250210017, 'alpha_actor': 0.9265439243309446}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:58:04,760] Trial 214 finished with value: 2.850762398804645 and parameters: {'alpha_critic': 0.9169336553190206, 'alpha_actor': 0.371088002335123}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:58:07,199] Trial 215 finished with value: 2.9110509063446415 and parameters: {'alpha_critic': 0.895698440437413, 'alpha_actor': 0.9607181803198817}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:58:09,937] Trial 216 finished with value: 2.8714836807496615 and parameters: {'alpha_critic': 0.9590214167430284, 'alpha_actor': 0.9647285940315146}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:58:12,399] Trial 217 finished with value: 2.8871516744354735 and parameters: {'alpha_critic': 0.942418495202092, 'alpha_actor': 0.9242168447176183}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:58:14,839] Trial 218 finished with value: 2.8952962261519106 and parameters: {'alpha_critic': 0.8949936691068342, 'alpha_actor': 0.8942930547253901}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:58:17,241] Trial 219 finished with value: 2.9085345580691335 and parameters: {'alpha_critic': 0.8595963103274447, 'alpha_actor': 0.9423591983393932}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:58:19,579] Trial 220 finished with value: 2.90051519038514 and parameters: {'alpha_critic': 0.8617058086627942, 'alpha_actor': 0.9448338557522078}. Best is trial 69 with value: 2.916861519962526.
# [I 2024-09-29 01:58:22,122] Trial 221 finished with value: 2.8890875231651 and parameters: {'alpha_critic': 0.901928907523298, 'alpha_actor': 0.9639101010335697}. Best is trial 69 with value: 2.916861519962526.
# ...
# [I 2024-09-29 02:02:47,687] Trial 327 finished with value: 2.8997458369868423 and parameters: {'alpha_critic': 0.9428404618942552, 'alpha_actor': 0.8964416188578911}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:02:50,131] Trial 328 finished with value: 2.901255802396253 and parameters: {'alpha_critic': 0.9068985989066406, 'alpha_actor': 0.8339782843846513}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:02:52,573] Trial 329 finished with value: 2.9083725118406885 and parameters: {'alpha_critic': 0.8789843413283922, 'alpha_actor': 0.8701910893877239}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:02:55,100] Trial 330 finished with value: 2.8911282060867234 and parameters: {'alpha_critic': 0.91409402739997, 'alpha_actor': 0.8512554633589633}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:02:57,412] Trial 331 finished with value: 2.914044918781489 and parameters: {'alpha_critic': 0.8830039779693952, 'alpha_actor': 0.9415859602836415}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:03,242] Trial 332 finished with value: 0.6166098491597816 and parameters: {'alpha_critic': 0.015606984859112105, 'alpha_actor': 0.9470785769102479}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:06,218] Trial 333 finished with value: 2.8062264546639013 and parameters: {'alpha_critic': 0.9511451398323998, 'alpha_actor': 0.2463661045990596}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:08,627] Trial 334 finished with value: 2.9082359349146043 and parameters: {'alpha_critic': 0.8527082573033089, 'alpha_actor': 0.967387709665101}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:11,099] Trial 335 finished with value: 2.887051608008451 and parameters: {'alpha_critic': 0.8047043662281066, 'alpha_actor': 0.9331998671170557}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:13,541] Trial 336 finished with value: 2.89790185095855 and parameters: {'alpha_critic': 0.8980918761986488, 'alpha_actor': 0.9573482654148523}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:16,049] Trial 337 finished with value: 2.898722454220391 and parameters: {'alpha_critic': 0.8732705182437285, 'alpha_actor': 0.9301573464695083}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:18,498] Trial 338 finished with value: 2.9025588214791918 and parameters: {'alpha_critic': 0.9219142641530673, 'alpha_actor': 0.9048647842995954}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:20,958] Trial 339 finished with value: 2.908068103978509 and parameters: {'alpha_critic': 0.8415366180591732, 'alpha_actor': 0.974814643103486}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:23,435] Trial 340 finished with value: 2.8980934560772584 and parameters: {'alpha_critic': 0.8923376799874907, 'alpha_actor': 0.9406963792649267}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:26,023] Trial 341 finished with value: 2.881183392136451 and parameters: {'alpha_critic': 0.9704355146224224, 'alpha_actor': 0.9194035183370157}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:28,495] Trial 342 finished with value: 2.8912194106512827 and parameters: {'alpha_critic': 0.8716598987732317, 'alpha_actor': 0.9597795837910846}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:30,872] Trial 343 finished with value: 2.9129582107626946 and parameters: {'alpha_critic': 0.8309588725589729, 'alpha_actor': 0.8951876018030981}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:33,259] Trial 344 finished with value: 2.8904042827259593 and parameters: {'alpha_critic': 0.8205672718506687, 'alpha_actor': 0.8926956401648956}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:35,719] Trial 345 finished with value: 2.9080599636885256 and parameters: {'alpha_critic': 0.8336179714161648, 'alpha_actor': 0.8746690492799152}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:38,174] Trial 346 finished with value: 2.9084599072223325 and parameters: {'alpha_critic': 0.8562832742899043, 'alpha_actor': 0.9982491654037903}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:40,809] Trial 347 finished with value: 2.8679368755958823 and parameters: {'alpha_critic': 0.7898447473309793, 'alpha_actor': 0.5736074614489448}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:43,367] Trial 348 finished with value: 2.8927464184566705 and parameters: {'alpha_critic': 0.8221677425880272, 'alpha_actor': 0.7012471147766084}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:45,776] Trial 349 finished with value: 2.8956992213788726 and parameters: {'alpha_critic': 0.8473710476441619, 'alpha_actor': 0.9014669539504477}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:48,116] Trial 350 finished with value: 2.897976243035966 and parameters: {'alpha_critic': 0.8813701320156748, 'alpha_actor': 0.944941313888588}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:50,591] Trial 351 finished with value: 2.897436302260836 and parameters: {'alpha_critic': 0.8604522265011971, 'alpha_actor': 0.9780753750578364}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:53,055] Trial 352 finished with value: 2.898830523517391 and parameters: {'alpha_critic': 0.8777941717362874, 'alpha_actor': 0.888234740336765}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:55,556] Trial 353 finished with value: 2.9011773672090095 and parameters: {'alpha_critic': 0.8398231704731131, 'alpha_actor': 0.9150401365874238}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:03:57,935] Trial 354 finished with value: 2.8975624784021847 and parameters: {'alpha_critic': 0.8916869051337492, 'alpha_actor': 0.9524158392499126}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:00,380] Trial 355 finished with value: 2.9086573002986578 and parameters: {'alpha_critic': 0.8608605642828651, 'alpha_actor': 0.9260932627581563}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:02,854] Trial 356 finished with value: 2.9002172526778103 and parameters: {'alpha_critic': 0.901658266954328, 'alpha_actor': 0.9757713402959561}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:05,569] Trial 357 finished with value: 2.8856360339398974 and parameters: {'alpha_critic': 0.926593434240037, 'alpha_actor': 0.8803455492313745}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:08,116] Trial 358 finished with value: 2.918116801955516 and parameters: {'alpha_critic': 0.8754254646340236, 'alpha_actor': 0.9004995731785091}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:10,546] Trial 359 finished with value: 2.9175060882897386 and parameters: {'alpha_critic': 0.8854524993564294, 'alpha_actor': 0.9095332059983992}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:13,519] Trial 360 finished with value: 2.8276955988965278 and parameters: {'alpha_critic': 0.9994664482463094, 'alpha_actor': 0.9006263796282151}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:15,979] Trial 361 finished with value: 2.8919478984124476 and parameters: {'alpha_critic': 0.9086991324466603, 'alpha_actor': 0.910410068504133}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:18,977] Trial 362 finished with value: 2.513892559751871 and parameters: {'alpha_critic': 0.26733216075980176, 'alpha_actor': 0.9305166873473862}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:21,438] Trial 363 finished with value: 2.901612223115429 and parameters: {'alpha_critic': 0.8193866133490086, 'alpha_actor': 0.8968513752505556}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:23,915] Trial 364 finished with value: 2.8944725627610723 and parameters: {'alpha_critic': 0.8858069000371083, 'alpha_actor': 0.9148078157809527}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:26,263] Trial 365 finished with value: 2.8697943566826862 and parameters: {'alpha_critic': 0.6783770253422468, 'alpha_actor': 0.9374098079196952}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:28,738] Trial 366 finished with value: 2.8914848050912973 and parameters: {'alpha_critic': 0.9397753066908561, 'alpha_actor': 0.8685384754817198}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:31,099] Trial 367 finished with value: 2.8929711820621224 and parameters: {'alpha_critic': 0.8430246145833237, 'alpha_actor': 0.8979928639901434}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:33,550] Trial 368 finished with value: 2.861596398780181 and parameters: {'alpha_critic': 0.6463121315663541, 'alpha_actor': 0.9409645119608643}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:36,014] Trial 369 finished with value: 2.9046580806297224 and parameters: {'alpha_critic': 0.8653619983195548, 'alpha_actor': 0.9184574445277075}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:38,503] Trial 370 finished with value: 2.9105303554905126 and parameters: {'alpha_critic': 0.9015656583184893, 'alpha_actor': 0.8838486877564339}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:40,932] Trial 371 finished with value: 2.909535311108356 and parameters: {'alpha_critic': 0.9224187561241101, 'alpha_actor': 0.8444600196862648}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:43,619] Trial 372 finished with value: 2.8515945651407515 and parameters: {'alpha_critic': 0.8029571405466608, 'alpha_actor': 0.4569553853112194}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:46,083] Trial 373 finished with value: 2.8942942780325995 and parameters: {'alpha_critic': 0.907243803268953, 'alpha_actor': 0.8782116524257102}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:48,627] Trial 374 finished with value: 2.8990575688219717 and parameters: {'alpha_critic': 0.9454045733241031, 'alpha_actor': 0.8597450035782374}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:51,058] Trial 375 finished with value: 2.9041797659463033 and parameters: {'alpha_critic': 0.873487241748901, 'alpha_actor': 0.8849251123336971}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:53,454] Trial 376 finished with value: 2.8933592988100107 and parameters: {'alpha_critic': 0.8959043296346714, 'alpha_actor': 0.906200186605285}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:55,837] Trial 377 finished with value: 2.899337616804414 and parameters: {'alpha_critic': 0.8495772520600674, 'alpha_actor': 0.8833446648539588}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:04:58,409] Trial 378 finished with value: 2.9027879980002256 and parameters: {'alpha_critic': 0.9272517332312102, 'alpha_actor': 0.8622802807199274}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:00,833] Trial 379 finished with value: 2.9119980522256075 and parameters: {'alpha_critic': 0.9032808848427196, 'alpha_actor': 0.8981370032507205}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:03,272] Trial 380 finished with value: 2.89866642889939 and parameters: {'alpha_critic': 0.8331183331919704, 'alpha_actor': 0.9165896674908353}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:08,181] Trial 381 finished with value: 1.3547941658068632 and parameters: {'alpha_critic': 0.050797032691623334, 'alpha_actor': 0.9315186155261592}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:10,610] Trial 382 finished with value: 2.8831406126323427 and parameters: {'alpha_critic': 0.736166605150837, 'alpha_actor': 0.8994593270680441}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:13,031] Trial 383 finished with value: 2.9110616357762273 and parameters: {'alpha_critic': 0.8669062014550952, 'alpha_actor': 0.9240585563204612}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:15,526] Trial 384 finished with value: 2.890724423269968 and parameters: {'alpha_critic': 0.8583738208135705, 'alpha_actor': 0.9113219621718575}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:18,090] Trial 385 finished with value: 2.9000214063866867 and parameters: {'alpha_critic': 0.8193432730813395, 'alpha_actor': 0.8991298425398044}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:20,591] Trial 386 finished with value: 2.899839098692867 and parameters: {'alpha_critic': 0.870073715570532, 'alpha_actor': 0.9269817469983654}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:23,025] Trial 387 finished with value: 2.8972641121033282 and parameters: {'alpha_critic': 0.839691037436043, 'alpha_actor': 0.8417273934940234}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:25,464] Trial 388 finished with value: 2.895365853408989 and parameters: {'alpha_critic': 0.8795569673453627, 'alpha_actor': 0.8719210443906793}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:27,841] Trial 389 finished with value: 2.9075796246268317 and parameters: {'alpha_critic': 0.853213605064102, 'alpha_actor': 0.9389376816815703}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:30,306] Trial 390 finished with value: 2.9045221061093742 and parameters: {'alpha_critic': 0.8805067232809408, 'alpha_actor': 0.9003527177135139}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:32,712] Trial 391 finished with value: 2.9018561806326066 and parameters: {'alpha_critic': 0.9166791179915247, 'alpha_actor': 0.9206103049860994}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:35,159] Trial 392 finished with value: 2.894206483634855 and parameters: {'alpha_critic': 0.7717506835966728, 'alpha_actor': 0.8216568933525381}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:37,542] Trial 393 finished with value: 2.910079431653543 and parameters: {'alpha_critic': 0.86310862243413, 'alpha_actor': 0.8860916754911533}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:40,075] Trial 394 finished with value: 2.9103573553643964 and parameters: {'alpha_critic': 0.8954175755495853, 'alpha_actor': 0.9454272982364617}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:42,672] Trial 395 finished with value: 2.8770142756787314 and parameters: {'alpha_critic': 0.8483155738772384, 'alpha_actor': 0.517739429044226}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:45,092] Trial 396 finished with value: 2.9063697119152283 and parameters: {'alpha_critic': 0.8048894083845822, 'alpha_actor': 0.9123489200095681}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:47,724] Trial 397 finished with value: 2.8794517274434837 and parameters: {'alpha_critic': 0.9588587107494199, 'alpha_actor': 0.8539687189692864}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:50,234] Trial 398 finished with value: 2.8941442764441305 and parameters: {'alpha_critic': 0.9085464807086048, 'alpha_actor': 0.9312396811666105}. Best is trial 286 with value: 2.9203500355809733.
# [I 2024-09-29 02:05:55,845] Trial 399 finished with value: 2.1127945466802607 and parameters: {'alpha_critic': 0.8759918392567445, 'alpha_actor': 0.03030265150225936}. Best is trial 286 with value: 2.9203500355809733.
# Best parameters: {'alpha_critic': 0.8616091421151508, 'alpha_actor': 0.8414187715610656}
# Best score: 2.9203500355809733

# %% [markdown]
# ## Best score Grid Search :
# - ***Best parameters:*** {'alpha_critic': 0.8436842105263158, 'alpha_actor': 1.0}
# - ***Best score:*** -7.862479894535781
# ## Best score Bayesian Optimization  :
# - ***Best parameters:*** {'alpha_critic': 0.804400103698065, 'alpha_actor': 0.9882472809398611}
# - ***Best score:*** -7.725128134667201
#
# ## GS - value norm
# Best parameters: {'alpha_critic': 0.8957894736842106, 'alpha_actor': 0.9478947368421053}
# Best score: 2.995090861297018
# ## BO - Value norm
# Best parameters: {'alpha_critic': 0.8616091421151508, 'alpha_actor': 0.8414187715610656}
# Best score: 2.9203500355809733

# %% [markdown]
# # Step 3: Statistical tests
#
# Now you have to compare the performance of the actor-critic algorithm tuned
# with all the best hyper-parameters you found before, using statistical tests.
#
# The functions below are provided to run Welch's T-test over learning curves.
# They have been adapted from a github repository: https://github.com/flowersteam/rl_stats
# You don't need to understand them in detail (though it is always a good idea to try to understand more code).

# %%
from scipy.stats import ttest_ind
import bootstrapped.bootstrap as bs
import bootstrapped.compare_functions as bs_compare
import bootstrapped.stats_functions as bs_stats

# %%
def compute_central_tendency_and_error(id_central, id_error, sample):

    try:
        id_error = int(id_error)
    except:
        pass

    if id_central == "mean":
        central = np.nanmean(sample, axis=1)
    elif id_central == "median":
        central = np.nanmedian(sample, axis=1)
    else:
        raise NotImplementedError

    if isinstance(id_error, int):
        low = np.nanpercentile(sample, q=int((100 - id_error) / 2), axis=1)
        high = np.nanpercentile(sample, q=int(100 - (100 - id_error) / 2), axis=1)
    elif id_error == "std":
        low = central - np.nanstd(sample, axis=1)
        high = central + np.nanstd(sample, axis=1)
    elif id_error == "sem":
        low = central - np.nanstd(sample, axis=1) / np.sqrt(sample.shape[0])
        high = central + np.nanstd(sample, axis=1) / np.sqrt(sample.shape[0])
    else:
        raise NotImplementedError

    return central, low, high

# %%
def run_test(test_id, data1, data2, alpha=0.05):
    """
    Compute tests comparing data1 and data2 with confidence level alpha
    :param test_id: (str) refers to what test should be used
    :param data1: (np.ndarray) sample 1
    :param data2: (np.ndarray) sample 2
    :param alpha: (float) confidence level of the test
    :return: (bool) if True, the null hypothesis is rejected
    """
    data1 = data1.squeeze()
    data2 = data2.squeeze()
    n1 = data1.size
    n2 = data2.size

    # perform Welch t-test":
    _, p = ttest_ind(data1, data2, equal_var=False)
    return p < alpha

# %% [markdown]
# This last function was adapted for the lab.

# %%
def perform_test(perf1, perf2, name1, name2, sample_size=20, downsampling_fact=5, confidence_level=0.01):

    perf1 = perf1.transpose()
    perf2 = perf2.transpose()
    nb_datapoints = perf1.shape[1]
    nb_steps = perf1.shape[0]

    legend = [name1, name2]

    # what do you want to plot ?
    id_central = 'mean' # "median"  # 
    id_error = 80  # (percentiles), also: 'std', 'sem'

    test_id = "Welch t-test"  # recommended
    
    sample1 = perf1[:, np.random.randint(0, nb_datapoints, sample_size)]
    sample2 = perf2[:, np.random.randint(0, nb_datapoints, sample_size)]

    steps = np.arange(0, nb_steps, downsampling_fact)
    sample1 = sample1[steps, :]
    sample2 = sample2[steps, :]

    # test
    sign_diff = np.zeros([len(steps)])
    for i in range(len(steps)):
        sign_diff[i] = run_test(
            test_id, sample1[i, :], sample2[i, :], alpha=confidence_level
        )

    central1, low1, high1 = compute_central_tendency_and_error(
        id_central, id_error, sample1
    )
    central2, low2, high2 = compute_central_tendency_and_error(
        id_central, id_error, sample2
    )

    # plot
    _, ax = plt.subplots(1, 1, figsize=(20, 10))
    lab1 = plt.xlabel("training steps")
    lab2 = plt.ylabel("performance")

    plt.plot(steps, central1, linewidth=7)
    plt.plot(steps, central2, linewidth=7)
    plt.fill_between(steps, low1, high1, alpha=0.3)
    plt.fill_between(steps, low2, high2, alpha=0.3)
    leg = ax.legend(legend, frameon=False)

    # plot significative difference as dots
    idx = np.argwhere(sign_diff == 1)
    y = max(np.nanmax(high1), np.nanmax(high2))
    plt.scatter(steps[idx], y * 1.05 * np.ones([idx.size]), s=100, c="k", marker="o")

    # style
    for line in leg.get_lines():
        line.set_linewidth(10.0)
    ax.spines["top"].set_linewidth(5)
    ax.spines["right"].set_linewidth(5)
    ax.spines["bottom"].set_linewidth(5)
    ax.spines["left"].set_linewidth(5)

    plt.savefig(
        f"./{name1}_{name2}.png", bbox_extra_artists=(leg, lab1, lab2), bbox_inches="tight", dpi=100
    )
    # plt.show()

# %% [markdown]
# ## Exercise 3
#
# As hyper-parameters, you will use:
#
# - naive tuning, that is a pair (0.5, 0.5) for the actor and critic learning rates,
# - the best hyper-parameters you found with the different tuning algorithms you used before.
#
# ### 1. For each set of hyper-parameters, collect a large dataset of learning curves.
#
# We suggest using 150 training episodes.
#
# ### 2. Perform statistical comparisons
#
# - Take two datasets of learning curves obtained with the hyper-parameters sets that you found with different tuning algorithms.
# - Use the ``` perform_test(...)``` function to compare each possible pair of sets.
#
# You should obtain an image for each pair you have tried.
# In this image, black dots signal the time step where there is a statistically significant difference between two learning curves.
#
#  ### 3. Conclude.

# %%
stats_bayesian_opt_mean_steps = np.load("./results/stats_bayesian_optimization_value_norm.npy", allow_pickle=True)
stats_grid_search_mean_steps = np.load("./results/stats_grid_search_value_norm.npy", allow_pickle=True)

# %%
top_k_bayes_opt_mean_steps = sorted(stats_bayesian_opt_mean_steps, key=lambda x: np.mean(x["evaluation_metrics"]["norm_v"]), reverse=True)
top_k_grid_search_mean_steps = sorted(stats_grid_search_mean_steps, key=lambda x: np.mean(x["evaluation_metrics"]["norm_v"]), reverse=True)



print("Bayesian Optimization - Top 1")
print("Metrics: ", top_k_bayes_opt_mean_steps[0]["evaluation_metrics"]) 
print("Params: ", top_k_bayes_opt_mean_steps[0]["params"])

print("Grid Search - Top 1")
print("Metrics: ", top_k_grid_search_mean_steps[0]["evaluation_metrics"])
print("Params: ", top_k_grid_search_mean_steps[0]["params"])
# Out:
# Bayesian Optimization - Top 1
# Metrics:  {'mean_steps': -11.718799999999996, 'policy_entropy': 21.820413257660853, 'value_stability': -0.5860787489889543, 'mean_reward': 0.9213333333333334, 'norm_v': 2.9203500355809733}
# Params:  {'alpha_critic': 0.8616091421151508, 'alpha_actor': 0.8414187715610656}
# Grid Search - Top 1
# Metrics:  {'mean_steps': -11.3432, 'policy_entropy': 22.25540670882689, 'value_stability': -0.5248759495698774, 'mean_reward': 0.9290666666666668, 'norm_v': 2.9141655525059136}
# Params:  {'alpha_critic': 0.9478947368421053, 'alpha_actor': 0.8957894736842106}

# %%
class AnalyseStatistique():
    @staticmethod
    def evaluate_actor_critic(best_params: dict, nb_episodes: int = 150, n_iter=15):
        
        best_alpha_critic = best_params["alpha_critic"]
        best_alpha_actor = best_params["alpha_actor"]
        
        results = {}

        for i, (alpha_critic, alpha_actor) in enumerate(zip(best_alpha_critic, best_alpha_actor)):

            print(f"Running actor-critic with alpha_critic: {alpha_critic}, alpha_actor: {alpha_actor}")
            

            env_v_list, env_time_list, env_mean_reward = [], [], []
            for env_i in envs:
                all_v_list, all_time_list, all_mean_reward = [], [], []
                for _ in range(n_iter):
                    _, _, v_list, time_list, reward_list = actor_critic(
                        env_i, alpha_critic=alpha_critic, alpha_actor=alpha_actor, nb_episodes=nb_episodes, timeout=config.timeout, render=False
                    )
                    all_v_list.append(v_list)
                    all_time_list.append(time_list)
                    all_mean_reward.append(reward_list)

                env_v_list.append(np.mean(all_v_list, axis=0))
                env_time_list.append(np.mean(all_time_list, axis=0))
                env_mean_reward.append(np.mean(all_mean_reward, axis=0))

            
            all_v_list = np.mean(env_v_list, axis=0)
            all_time_list = np.mean(env_time_list, axis=0)
            all_mean_reward = np.mean(env_mean_reward, axis=0)

            results[i] = {
                "statistical_lists": {
                    "all_v_list": np.array(env_v_list),
                    "all_time_list": np.array(env_time_list),
                    "all_mean_reward": np.array(env_mean_reward),
                },
                "lists": {
                    "v_list": all_v_list,
                    "time_list": all_time_list,
                    "mean_reward": all_mean_reward,
                },
                "name" : f"alpha_critic: {np.round(alpha_critic,3)}, alpha_actor: {np.round(alpha_actor,3)}",
                "id": i
            }

        return results
    
    @staticmethod
    def compare_statistical_performance(results:dict):
        names = {
            0: "Default",
            1: "Bayesian Optimization - Value Norm",
            2: "Grid Search - Value Norm",
            3: "Bayesian Optimization - Mean Steps",
            4: "Grid Search - Mean Steps",
        }
        
        for i in range(len(results)-1):
            if i == 0:
                continue
            for j in range(i+1, len(results)):
                if j == 2:
                    continue
                name, name2 = names[i], names[j]
                perform_test(results[i]['statistical_lists']["all_time_list"], results[j]['statistical_lists']["all_time_list"], name, name2+" steps")
                perform_test(results[i]['statistical_lists']["all_mean_reward"], results[j]['statistical_lists']["all_mean_reward"], name, name2+" reward")
                perform_test(results[i]['statistical_lists']["all_v_list"], results[j]['statistical_lists']["all_v_list"], name, name2+" value norm")

# %%
best_params = {
    "alpha_critic": [
        0.5, 
        np.float64(top_k_bayes_opt_mean_steps[0]["params"]["alpha_critic"]), 
        np.float64(top_k_grid_search_mean_steps[0]["params"]["alpha_critic"]),
        0.804400103698065,
        0.8436842105263158,
    ],
    "alpha_actor": [
        0.5, 
        np.float64(top_k_bayes_opt_mean_steps[0]["params"]["alpha_actor"]), 
        np.float64(top_k_grid_search_mean_steps[0]["params"]["alpha_actor"]),
        0.9882472809398611,
        1.0,
    ],
}

results = AnalyseStatistique.evaluate_actor_critic(best_params, nb_episodes=150)
# Out:
# Running actor-critic with alpha_critic: 0.5, alpha_actor: 0.5
# /mnt/c/Cours-Sorbonne/M2/UE_DEEP/.venv/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.gamma to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.gamma` for environment variables or `env.get_wrapper_attr('gamma')` that will search the reminding wrappers.
#   logger.warn(
# Running actor-critic with alpha_critic: 0.8616091421151508, alpha_actor: 0.8414187715610656
# Running actor-critic with alpha_critic: 0.9478947368421053, alpha_actor: 0.8957894736842106
# Running actor-critic with alpha_critic: 0.804400103698065, alpha_actor: 0.9882472809398611
# Running actor-critic with alpha_critic: 0.8436842105263158, alpha_actor: 1.0

# %%
Plotter.compare_plots(results)
# Out:
# invalid command name "140358276124160process_stream_events"
#     while executing
# "140358276124160process_stream_events"
#     ("after" script)
# can't invoke "event" command: application has been destroyed
#     while executing
# "event generate $w <<ThemeChanged>>"
#     (procedure "ttk::ThemeChanged" line 6)
#     invoked from within
# "ttk::ThemeChanged"

# %%
AnalyseStatistique.compare_statistical_performance(results)
# Out:
# /mnt/c/Cours-Sorbonne/M2/UE_DEEP/.venv/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# # Lab report
#
# Your report should contain:
# - your source code (probably this notebook), do not forget to put your names on top of the notebook,
# - in a separate pdf file with your names in the name of the file:
#     + a detailed enough description of the choices you have made: the parameters you have set, the libraries you have used, etc.,
#     + the heatmaps obtained using the hyper-parameters tuning algorithms that you have used,
#     + the figures resulting from performing Welch's T-test using the best hyper-parameters from the above approaches,
#     + your conclusion from these experiments.
#
# Beyond the elements required in this report, any additional studies will be rewarded.
# For instance, you can try using a Q-function as critic, using random search as hyper-parameters tuning algorithm,
# using more challenging environments, etc.
